# %% [markdown]
# # リポジトリクローン

# %%
# !git clone https://github.com/lyuwenyu/RT-DETR
# %cd RT-DETR/rtdetrv2_pytorch
# Out:
# Cloning into 'RT-DETR'...
# remote: Enumerating objects: 962, done.
# remote: Counting objects: 100% (444/444), done.
# remote: Compressing objects: 100% (218/218), done.
# remote: Total 962 (delta 312), reused 230 (delta 226), pack-reused 518 (from 1)
# Receiving objects: 100% (962/962), 591.41 KiB | 4.89 MiB/s, done.
# Resolving deltas: 100% (470/470), done.
# /content/RT-DETR/rtdetrv2_pytorch

# %%
# !mkdir checkpoints

# %% [markdown]
# # パッケージインストール

# %%
# !pip install -q onnx onnxruntime onnxsim
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 74.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00

# %% [markdown]
# # データセット準備（VOC→COCO形式）

# %%
# %cd /content
# !git clone https://github.com/Kazuhito00/YOLOX-Colaboratory-Training-Sample.git
# !git clone https://github.com/Kazuhito00/convert_voc_to_coco.git
# %cd RT-DETR/rtdetrv2_pytorch
# Out:
# /content
# Cloning into 'YOLOX-Colaboratory-Training-Sample'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 187 (delta 22), reused 18 (delta 18), pack-reused 161 (from 1)
# Receiving objects: 100% (187/187), 30.13 MiB | 48.36 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into 'convert_voc_to_coco'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 12), reused 14 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 11.77 KiB | 11.77 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/RT-DETR/rtdetrv2_pytorch

# %%
dataset_directory = '/content/YOLOX-Colaboratory-Training-Sample/02.annotation_data'

# %%
import os

# 学習/検証データパス(train/validation data path)
train_directory = './train'
validation_directory = './validation'

# 学習データ格納ディレクトリ作成(Create training data storage directory)
os.makedirs(train_directory, exist_ok=True)
# 検証データ格納ディレクトリ作成(Create verification data storage directory)
os.makedirs(validation_directory, exist_ok=True)

# %%
import glob
import shutil
import random

# 学習データの割合(Percentage of training data)
train_ratio = 0.8

# コピー元ファイルリスト取得(Get copy source file list)
annotation_list = sorted(glob.glob(dataset_directory + '/*.xml'))
image_list = sorted(glob.glob(dataset_directory + '/*.jpg'))

file_num = len(annotation_list)

# インデックスシャッフル(shuffle)
index_list = list(range(file_num - 1))
random.shuffle(index_list)

for count, index in enumerate(index_list):
    if count < int(file_num * train_ratio):
        # 学習用データ(Training Data)
        shutil.copy2(annotation_list[index], train_directory)
        shutil.copy2(image_list[index], train_directory)
    else:
        # 検証用データ(Validation Data)
        shutil.copy2(annotation_list[index], validation_directory)
        shutil.copy2(image_list[index], validation_directory)

# %%
# Pascal VOC形式 を MS COCO形式へ変換
# !python ../../convert_voc_to_coco/convert_voc_to_coco.py \
    train train/train_annotations.json \
    --start_image_id=0
# !python ../../convert_voc_to_coco/convert_voc_to_coco.py \
    validation validation/validation_annotations.json \
    --start_image_id=10000000
# Out:
# Number of xml files: 40
# Convert XML to JSON: 100% 40/40 [00:00<00:00, 6584.98it/s]
# {'Fish': 221}
# Success: train/train_annotations.json
# Number of xml files: 9
# Convert XML to JSON: 100% 9/9 [00:00<00:00, 6071.86it/s]
# {'Fish': 48}
# Success: validation/validation_annotations.json

# %% [markdown]
# # 学習設定yml準備

# %%
# %%writefile my_coco_detection.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/dataset/coco_detection.yml を参考
#
# task: detection
#
# evaluator:
#   type: CocoEvaluator
#   iou_types: ['bbox', ]
#
# num_classes: 1                                # 変更
# remap_mscoco_category: True
#
# train_dataloader:
#   type: DataLoader
#   dataset:
#     type: CocoDetection
#     img_folder: ./train/                      # 変更
#     ann_file: ./train/train_annotations.json  # 変更
#     return_masks: False
#     transforms:
#       type: Compose
#       ops: ~
#   shuffle: True
#   num_workers: 4
#   drop_last: True
#   collate_fn:
#     type: BatchImageCollateFuncion
#
#
# val_dataloader:
#   type: DataLoader
#   dataset:
#     type: CocoDetection
#     img_folder: ./validation/                           # 変更
#     ann_file: ./validation/validation_annotations.json  # 変更
#     return_masks: False
#     transforms:
#       type: Compose
#       ops: ~
#   shuffle: False
#   num_workers: 4
#   drop_last: False
#   collate_fn:
#     type: BatchImageCollateFuncion
# Out:
# Writing my_coco_detection.yml

# %%
# %%writefile my_runtime.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/runtime.yml を参考（今回のサンプルでは変更なし）
#
# print_freq: 100
# output_dir: './logs'
# checkpoint_freq: 1
#
#
# sync_bn: True
# find_unused_parameters: False
#
#
# use_amp: False
# scaler:
#   type: GradScaler
#   enabled: True
#
#
# use_ema: False
# ema:
#   type: ModelEMA
#   decay: 0.9999
#   warmups: 2000
# Out:
# Writing my_runtime.yml

# %%
# %%writefile my_dataloader.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/dataloader.yml を参考（今回のサンプルでは変更なし）
#
#
# train_dataloader:
#   dataset:
#     transforms:
#       ops:
#         - {type: RandomPhotometricDistort, p: 0.5}
#         - {type: RandomZoomOut, fill: 0}
#         - {type: RandomIoUCrop, p: 0.8}
#         - {type: SanitizeBoundingBoxes, min_size: 1}
#         - {type: RandomHorizontalFlip}
#         - {type: Resize, size: [640, 640], }
#         - {type: SanitizeBoundingBoxes, min_size: 1}
#         - {type: ConvertPILImage, dtype: 'float32', scale: True}
#         - {type: ConvertBoxes, fmt: 'cxcywh', normalize: True}
#       policy:
#         name: stop_epoch
#         epoch: 71 # epoch in [71, ~) stop `ops`
#         ops: ['RandomPhotometricDistort', 'RandomZoomOut', 'RandomIoUCrop']
#
#   collate_fn:
#     type: BatchImageCollateFuncion
#     scales: [480, 512, 544, 576, 608, 640, 640, 640, 672, 704, 736, 768, 800]
#     stop_epoch: 71 # epoch in [71, ~) stop `multiscales`
#
#   shuffle: True
#   total_batch_size: 16 # total batch size equals to 16 (4 * 4)
#   num_workers: 4
#
#
# val_dataloader:
#   dataset:
#     transforms:
#       ops:
#         - {type: Resize, size: [640, 640]}
#         - {type: ConvertPILImage, dtype: 'float32', scale: True}
#   shuffle: False
#   total_batch_size: 32
#   num_workers: 4
# Out:
# Writing my_dataloader.yml

# %%
# %%writefile my_optimizer.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/optimizer.yml を参考（今回のサンプルでは変更なし）
#
# use_amp: True
# use_ema: True
# ema:
#   type: ModelEMA
#   decay: 0.9999
#   warmups: 2000
#
#
# epoches: 72
# clip_max_norm: 0.1
#
#
# optimizer:
#   type: AdamW
#   params:
#     -
#       params: '^(?=.*backbone)(?!.*norm).*$'
#       lr: 0.00001
#     -
#       params: '^(?=.*(?:encoder|decoder))(?=.*(?:norm|bn)).*$'
#       weight_decay: 0.
#
#   lr: 0.0001
#   betas: [0.9, 0.999]
#   weight_decay: 0.0001
#
#
# lr_scheduler:
#   type: MultiStepLR
#   milestones: [1000]
#   gamma: 0.1
#
#
# lr_warmup_scheduler:
#   type: LinearWarmup
#   warmup_duration: 2000
# Out:
# Writing my_optimizer.yml

# %%
# %%writefile my_rtdetrv2_r50vd.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/rtdetrv2_r50vd.yml を参考（今回のサンプルでは変更なし）
#
# task: detection
#
# model: RTDETR
# criterion: RTDETRCriterionv2
# postprocessor: RTDETRPostProcessor
#
#
# use_focal_loss: True
# eval_spatial_size: [640, 640] # h w
#
#
# RTDETR:
#   backbone: PResNet
#   encoder: HybridEncoder
#   decoder: RTDETRTransformerv2
#
#
# PResNet:
#   depth: 50
#   variant: d
#   freeze_at: 0
#   return_idx: [1, 2, 3]
#   num_stages: 4
#   freeze_norm: True
#   pretrained: True
#
#
# HybridEncoder:
#   in_channels: [512, 1024, 2048]
#   feat_strides: [8, 16, 32]
#
#   # intra
#   hidden_dim: 256
#   use_encoder_idx: [2]
#   num_encoder_layers: 1
#   nhead: 8
#   dim_feedforward: 1024
#   dropout: 0.
#   enc_act: 'gelu'
#
#   # cross
#   expansion: 1.0
#   depth_mult: 1
#   act: 'silu'
#
#
# RTDETRTransformerv2:
#   feat_channels: [256, 256, 256]
#   feat_strides: [8, 16, 32]
#   hidden_dim: 256
#   num_levels: 3
#
#   num_layers: 6
#   num_queries: 300
#
#   num_denoising: 100
#   label_noise_ratio: 0.5
#   box_noise_scale: 1.0 # 1.0 0.4
#
#   eval_idx: -1
#
#   # NEW
#   num_points: [4, 4, 4] # [3,3,3] [2,2,2]
#   cross_attn_method: default # default, discrete
#   query_select_method: default # default, agnostic
#
#
# RTDETRPostProcessor:
#   num_top_queries: 300
#
#
# RTDETRCriterionv2:
#   weight_dict: {loss_vfl: 1, loss_bbox: 5, loss_giou: 2,}
#   losses: ['vfl', 'boxes', ]
#   alpha: 0.75
#   gamma: 2.0
#
#   matcher:
#     type: HungarianMatcher
#     weight_dict: {cost_class: 2, cost_bbox: 5, cost_giou: 2}
#     alpha: 0.25
#     gamma: 2.0
# Out:
# Writing my_rtdetrv2_r50vd.yml

# %%
# %%writefile my_rtdetrv2_r18vd.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/rtdetrv2_r18vd_120e_coco.yml を参考
#
# __include__: [
#   './my_coco_detection.yml',            # 変更
#   './my_runtime.yml',                   # 変更
#   './my_dataloader.yml',                # 変更
#   './my_optimizer.yml',                 # 変更
#   './my_rtdetrv2_r50vd.yml',            # 変更
# ]
#
#
# output_dir: ./output/my_rtdetrv2_r18vd  # 変更
#
#
# PResNet:
#   depth: 18
#   freeze_at: -1
#   freeze_norm: False
#   pretrained: True
#
#
# HybridEncoder:
#   in_channels: [128, 256, 512]
#   hidden_dim: 256
#   expansion: 0.5
#
#
# RTDETRTransformerv2:
#   num_layers: 3
#
#
# epoches: 300                            # 変更
#
# optimizer:
#   type: AdamW
#   params:
#     -
#       params: '^(?=.*(?:norm|bn)).*$'
#       weight_decay: 0.
#
#
# train_dataloader:
#   dataset:
#     transforms:
#       policy:
#         epoch: 117
#   collate_fn:
#     scales: ~
# Out:
# Writing my_rtdetrv2_r18vd.yml

# %% [markdown]
# # 学習実施

# %%
# Colaboratory用に変更
# CUDA_VISIBLE_DEVICES=0,1,2,3 torchrun --master_port=9909 --nproc_per_node=4 tools/train.py -c path/to/config -t path/to/checkpoint --use-amp --seed=0 &> log.txt 2>&1 &
# !python tools/train.py -c my_rtdetrv2_r18vd.yml --use-amp --seed=0
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 82, 'coco_eval_bbox': 0.016288086809559534}
# Epoch: [83]  [0/2]  eta: 0:00:04  lr: 0.000008  loss: 16.7722 (16.7722)  loss_vfl: 0.4590 (0.4590)  loss_bbox: 0.7201 (0.7201)  loss_giou: 1.3375 (1.3375)  loss_vfl_aux_0: 0.4080 (0.4080)  loss_bbox_aux_0: 0.7484 (0.7484)  loss_giou_aux_0: 1.3465 (1.3465)  loss_vfl_aux_1: 0.4429 (0.4429)  loss_bbox_aux_1: 0.7392 (0.7392)  loss_giou_aux_1: 1.3408 (1.3408)  loss_vfl_dn_0: 0.3198 (0.3198)  loss_bbox_dn_0: 0.5572 (0.5572)  loss_giou_dn_0: 1.3776 (1.3776)  loss_vfl_dn_1: 0.3169 (0.3169)  loss_bbox_dn_1: 0.5561 (0.5561)  loss_giou_dn_1: 1.3744 (1.3744)  loss_vfl_dn_2: 0.3203 (0.3203)  loss_bbox_dn_2: 0.5550 (0.5550)  loss_giou_dn_2: 1.3706 (1.3706)  loss_vfl_enc_0: 0.3743 (0.3743)  loss_bbox_enc_0: 0.7589 (0.7589)  loss_giou_enc_0: 1.3488 (1.3488)  time: 2.4921  data: 1.7591  max mem: 6448
# Epoch: [83]  [1/2]  eta: 0:00:01  lr: 0.000008  loss: 16.7722 (17.2507)  loss_vfl: 0.4089 (0.4340)  loss_bbox: 0.7201 (0.8114)  loss_giou: 1.3375 (1.3703)  loss_vfl_aux_0: 0.3640 (0.3860)  loss_bbox_aux_0: 0.7484 (0.8367)  loss_giou_aux_0: 1.3465 (1.3846)  loss_vfl_aux_1: 0.4194 (0.4312)  loss_bbox_aux_1: 0.7392 (0.8268)  loss_giou_aux_1: 1.3408 (1.3742)  loss_vfl_dn_0: 0.3198 (0.3251)  loss_bbox_dn_0: 0.5572 (0.5764)  loss_giou_dn_0: 1.3578 (1.3677)  loss_vfl_dn_1: 0.3169 (0.3252)  loss_bbox_dn_1: 0.5561 (0.5753)  loss_giou_dn_1: 1.3546 (1.3645)  loss_vfl_dn_2: 0.3203 (0.3259)  loss_bbox_dn_2: 0.5550 (0.5741)  loss_giou_dn_2: 1.3512 (1.3609)  loss_vfl_enc_0: 0.3276 (0.3510)  loss_bbox_enc_0: 0.7589 (0.8598)  loss_giou_enc_0: 1.3488 (1.3896)  time: 1.5772  data: 0.8796  max mem: 6448
# Epoch: [83] Total time: 0:00:03 (1.6008 s / it)
# Averaged stats: lr: 0.000008  loss: 16.7722 (17.2507)  loss_vfl: 0.4089 (0.4340)  loss_bbox: 0.7201 (0.8114)  loss_giou: 1.3375 (1.3703)  loss_vfl_aux_0: 0.3640 (0.3860)  loss_bbox_aux_0: 0.7484 (0.8367)  loss_giou_aux_0: 1.3465 (1.3846)  loss_vfl_aux_1: 0.4194 (0.4312)  loss_bbox_aux_1: 0.7392 (0.8268)  loss_giou_aux_1: 1.3408 (1.3742)  loss_vfl_dn_0: 0.3198 (0.3251)  loss_bbox_dn_0: 0.5572 (0.5764)  loss_giou_dn_0: 1.3578 (1.3677)  loss_vfl_dn_1: 0.3169 (0.3252)  loss_bbox_dn_1: 0.5561 (0.5753)  loss_giou_dn_1: 1.3546 (1.3645)  loss_vfl_dn_2: 0.3203 (0.3259)  loss_bbox_dn_2: 0.5550 (0.5741)  loss_giou_dn_2: 1.3512 (1.3609)  loss_vfl_enc_0: 0.3276 (0.3510)  loss_bbox_enc_0: 0.7589 (0.8598)  loss_giou_enc_0: 1.3488 (1.3896)
# Test:  [0/1]  eta: 0:00:00    time: 0.8900  data: 0.4710  max mem: 6448
# Test: Total time: 0:00:00 (0.9312 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 82, 'coco_eval_bbox': 0.016288086809559534}
# Epoch: [84]  [0/2]  eta: 0:00:05  lr: 0.000009  loss: 17.3164 (17.3164)  loss_vfl: 0.4282 (0.4282)  loss_bbox: 0.8267 (0.8267)  loss_giou: 1.4147 (1.4147)  loss_vfl_aux_0: 0.3474 (0.3474)  loss_bbox_aux_0: 0.8423 (0.8423)  loss_giou_aux_0: 1.4259 (1.4259)  loss_vfl_aux_1: 0.4207 (0.4207)  loss_bbox_aux_1: 0.8300 (0.8300)  loss_giou_aux_1: 1.4181 (1.4181)  loss_vfl_dn_0: 0.3176 (0.3176)  loss_bbox_dn_0: 0.5507 (0.5507)  loss_giou_dn_0: 1.3877 (1.3877)  loss_vfl_dn_1: 0.3149 (0.3149)  loss_bbox_dn_1: 0.5494 (0.5494)  loss_giou_dn_1: 1.3832 (1.3832)  loss_vfl_dn_2: 0.3135 (0.3135)  loss_bbox_dn_2: 0.5482 (0.5482)  loss_giou_dn_2: 1.3792 (1.3792)  loss_vfl_enc_0: 0.3286 (0.3286)  loss_bbox_enc_0: 0.8503 (0.8503)  loss_giou_enc_0: 1.4390 (1.4390)  time: 2.6526  data: 1.9478  max mem: 6448
# Epoch: [84]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 16.0401 (16.6783)  loss_vfl: 0.4231 (0.4257)  loss_bbox: 0.6302 (0.7285)  loss_giou: 1.3268 (1.3708)  loss_vfl_aux_0: 0.3474 (0.3608)  loss_bbox_aux_0: 0.6526 (0.7475)  loss_giou_aux_0: 1.3348 (1.3803)  loss_vfl_aux_1: 0.4207 (0.4207)  loss_bbox_aux_1: 0.6356 (0.7328)  loss_giou_aux_1: 1.3266 (1.3724)  loss_vfl_dn_0: 0.3176 (0.3192)  loss_bbox_dn_0: 0.5034 (0.5270)  loss_giou_dn_0: 1.3574 (1.3726)  loss_vfl_dn_1: 0.3149 (0.3208)  loss_bbox_dn_1: 0.5020 (0.5257)  loss_giou_dn_1: 1.3536 (1.3684)  loss_vfl_dn_2: 0.3135 (0.3203)  loss_bbox_dn_2: 0.5007 (0.5245)  loss_giou_dn_2: 1.3502 (1.3647)  loss_vfl_enc_0: 0.3286 (0.3435)  loss_bbox_enc_0: 0.6713 (0.7608)  loss_giou_enc_0: 1.3439 (1.3914)  time: 1.6615  data: 0.9740  max mem: 6448
# Epoch: [84] Total time: 0:00:03 (1.6853 s / it)
# Averaged stats: lr: 0.000009  loss: 16.0401 (16.6783)  loss_vfl: 0.4231 (0.4257)  loss_bbox: 0.6302 (0.7285)  loss_giou: 1.3268 (1.3708)  loss_vfl_aux_0: 0.3474 (0.3608)  loss_bbox_aux_0: 0.6526 (0.7475)  loss_giou_aux_0: 1.3348 (1.3803)  loss_vfl_aux_1: 0.4207 (0.4207)  loss_bbox_aux_1: 0.6356 (0.7328)  loss_giou_aux_1: 1.3266 (1.3724)  loss_vfl_dn_0: 0.3176 (0.3192)  loss_bbox_dn_0: 0.5034 (0.5270)  loss_giou_dn_0: 1.3574 (1.3726)  loss_vfl_dn_1: 0.3149 (0.3208)  loss_bbox_dn_1: 0.5020 (0.5257)  loss_giou_dn_1: 1.3536 (1.3684)  loss_vfl_dn_2: 0.3135 (0.3203)  loss_bbox_dn_2: 0.5007 (0.5245)  loss_giou_dn_2: 1.3502 (1.3647)  loss_vfl_enc_0: 0.3286 (0.3435)  loss_bbox_enc_0: 0.6713 (0.7608)  loss_giou_enc_0: 1.3439 (1.3914)
# Test:  [0/1]  eta: 0:00:00    time: 0.8394  data: 0.4268  max mem: 6448
# Test: Total time: 0:00:00 (0.8867 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 84, 'coco_eval_bbox': 0.016945310258271017}
# Epoch: [85]  [0/2]  eta: 0:00:05  lr: 0.000009  loss: 15.9021 (15.9021)  loss_vfl: 0.4829 (0.4829)  loss_bbox: 0.6078 (0.6078)  loss_giou: 1.2719 (1.2719)  loss_vfl_aux_0: 0.4368 (0.4368)  loss_bbox_aux_0: 0.6178 (0.6178)  loss_giou_aux_0: 1.2842 (1.2842)  loss_vfl_aux_1: 0.4692 (0.4692)  loss_bbox_aux_1: 0.6111 (0.6111)  loss_giou_aux_1: 1.2798 (1.2798)  loss_vfl_dn_0: 0.3025 (0.3025)  loss_bbox_dn_0: 0.4883 (0.4883)  loss_giou_dn_0: 1.3836 (1.3836)  loss_vfl_dn_1: 0.3044 (0.3044)  loss_bbox_dn_1: 0.4867 (0.4867)  loss_giou_dn_1: 1.3796 (1.3796)  loss_vfl_dn_2: 0.3125 (0.3125)  loss_bbox_dn_2: 0.4850 (0.4850)  loss_giou_dn_2: 1.3755 (1.3755)  loss_vfl_enc_0: 0.3804 (0.3804)  loss_bbox_enc_0: 0.6388 (0.6388)  loss_giou_enc_0: 1.3031 (1.3031)  time: 2.5615  data: 1.8521  max mem: 6448
# Epoch: [85]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 15.8801 (15.8911)  loss_vfl: 0.4272 (0.4551)  loss_bbox: 0.6078 (0.6218)  loss_giou: 1.2719 (1.2935)  loss_vfl_aux_0: 0.3860 (0.4114)  loss_bbox_aux_0: 0.6178 (0.6421)  loss_giou_aux_0: 1.2842 (1.3139)  loss_vfl_aux_1: 0.4280 (0.4486)  loss_bbox_aux_1: 0.6111 (0.6283)  loss_giou_aux_1: 1.2798 (1.3018)  loss_vfl_dn_0: 0.3025 (0.3065)  loss_bbox_dn_0: 0.4452 (0.4668)  loss_giou_dn_0: 1.3695 (1.3766)  loss_vfl_dn_1: 0.3044 (0.3101)  loss_bbox_dn_1: 0.4437 (0.4652)  loss_giou_dn_1: 1.3649 (1.3723)  loss_vfl_dn_2: 0.3125 (0.3173)  loss_bbox_dn_2: 0.4423 (0.4636)  loss_giou_dn_2: 1.3605 (1.3680)  loss_vfl_enc_0: 0.3420 (0.3612)  loss_bbox_enc_0: 0.6388 (0.6503)  loss_giou_enc_0: 1.3031 (1.3169)  time: 1.6171  data: 0.9261  max mem: 6448
# Epoch: [85] Total time: 0:00:03 (1.6455 s / it)
# Averaged stats: lr: 0.000009  loss: 15.8801 (15.8911)  loss_vfl: 0.4272 (0.4551)  loss_bbox: 0.6078 (0.6218)  loss_giou: 1.2719 (1.2935)  loss_vfl_aux_0: 0.3860 (0.4114)  loss_bbox_aux_0: 0.6178 (0.6421)  loss_giou_aux_0: 1.2842 (1.3139)  loss_vfl_aux_1: 0.4280 (0.4486)  loss_bbox_aux_1: 0.6111 (0.6283)  loss_giou_aux_1: 1.2798 (1.3018)  loss_vfl_dn_0: 0.3025 (0.3065)  loss_bbox_dn_0: 0.4452 (0.4668)  loss_giou_dn_0: 1.3695 (1.3766)  loss_vfl_dn_1: 0.3044 (0.3101)  loss_bbox_dn_1: 0.4437 (0.4652)  loss_giou_dn_1: 1.3649 (1.3723)  loss_vfl_dn_2: 0.3125 (0.3173)  loss_bbox_dn_2: 0.4423 (0.4636)  loss_giou_dn_2: 1.3605 (1.3680)  loss_vfl_enc_0: 0.3420 (0.3612)  loss_bbox_enc_0: 0.6388 (0.6503)  loss_giou_enc_0: 1.3031 (1.3169)
# Test:  [0/1]  eta: 0:00:00    time: 0.8479  data: 0.4469  max mem: 6448
# Test: Total time: 0:00:00 (0.8923 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 85, 'coco_eval_bbox': 0.01895057111018066}
# Epoch: [86]  [0/2]  eta: 0:00:04  lr: 0.000009  loss: 16.3694 (16.3694)  loss_vfl: 0.4297 (0.4297)  loss_bbox: 0.7074 (0.7074)  loss_giou: 1.3760 (1.3760)  loss_vfl_aux_0: 0.3652 (0.3652)  loss_bbox_aux_0: 0.7305 (0.7305)  loss_giou_aux_0: 1.3926 (1.3926)  loss_vfl_aux_1: 0.4163 (0.4163)  loss_bbox_aux_1: 0.7081 (0.7081)  loss_giou_aux_1: 1.3849 (1.3849)  loss_vfl_dn_0: 0.3203 (0.3203)  loss_bbox_dn_0: 0.4558 (0.4558)  loss_giou_dn_0: 1.3587 (1.3587)  loss_vfl_dn_1: 0.3186 (0.3186)  loss_bbox_dn_1: 0.4546 (0.4546)  loss_giou_dn_1: 1.3546 (1.3546)  loss_vfl_dn_2: 0.3247 (0.3247)  loss_bbox_dn_2: 0.4534 (0.4534)  loss_giou_dn_2: 1.3505 (1.3505)  loss_vfl_enc_0: 0.3264 (0.3264)  loss_bbox_enc_0: 0.7351 (0.7351)  loss_giou_enc_0: 1.4060 (1.4060)  time: 2.4639  data: 1.7569  max mem: 6448
# Epoch: [86]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 16.2557 (16.3125)  loss_vfl: 0.4297 (0.4373)  loss_bbox: 0.6640 (0.6857)  loss_giou: 1.2718 (1.3239)  loss_vfl_aux_0: 0.3652 (0.3978)  loss_bbox_aux_0: 0.6803 (0.7054)  loss_giou_aux_0: 1.2637 (1.3282)  loss_vfl_aux_1: 0.4163 (0.4365)  loss_bbox_aux_1: 0.6645 (0.6863)  loss_giou_aux_1: 1.2706 (1.3278)  loss_vfl_dn_0: 0.3203 (0.3207)  loss_bbox_dn_0: 0.4558 (0.5032)  loss_giou_dn_0: 1.3587 (1.3666)  loss_vfl_dn_1: 0.3174 (0.3180)  loss_bbox_dn_1: 0.4546 (0.5016)  loss_giou_dn_1: 1.3546 (1.3623)  loss_vfl_dn_2: 0.3247 (0.3260)  loss_bbox_dn_2: 0.4534 (0.5001)  loss_giou_dn_2: 1.3505 (1.3581)  loss_vfl_enc_0: 0.3264 (0.3641)  loss_bbox_enc_0: 0.6883 (0.7117)  loss_giou_enc_0: 1.2966 (1.3513)  time: 1.5892  data: 0.8963  max mem: 6448
# Epoch: [86] Total time: 0:00:03 (1.6210 s / it)
# Averaged stats: lr: 0.000009  loss: 16.2557 (16.3125)  loss_vfl: 0.4297 (0.4373)  loss_bbox: 0.6640 (0.6857)  loss_giou: 1.2718 (1.3239)  loss_vfl_aux_0: 0.3652 (0.3978)  loss_bbox_aux_0: 0.6803 (0.7054)  loss_giou_aux_0: 1.2637 (1.3282)  loss_vfl_aux_1: 0.4163 (0.4365)  loss_bbox_aux_1: 0.6645 (0.6863)  loss_giou_aux_1: 1.2706 (1.3278)  loss_vfl_dn_0: 0.3203 (0.3207)  loss_bbox_dn_0: 0.4558 (0.5032)  loss_giou_dn_0: 1.3587 (1.3666)  loss_vfl_dn_1: 0.3174 (0.3180)  loss_bbox_dn_1: 0.4546 (0.5016)  loss_giou_dn_1: 1.3546 (1.3623)  loss_vfl_dn_2: 0.3247 (0.3260)  loss_bbox_dn_2: 0.4534 (0.5001)  loss_giou_dn_2: 1.3505 (1.3581)  loss_vfl_enc_0: 0.3264 (0.3641)  loss_bbox_enc_0: 0.6883 (0.7117)  loss_giou_enc_0: 1.2966 (1.3513)
# Test:  [0/1]  eta: 0:00:00    time: 0.8752  data: 0.4381  max mem: 6448
# Test: Total time: 0:00:00 (0.9267 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 85, 'coco_eval_bbox': 0.01895057111018066}
# Epoch: [87]  [0/2]  eta: 0:00:04  lr: 0.000009  loss: 17.1898 (17.1898)  loss_vfl: 0.3848 (0.3848)  loss_bbox: 0.8169 (0.8169)  loss_giou: 1.4207 (1.4207)  loss_vfl_aux_0: 0.3518 (0.3518)  loss_bbox_aux_0: 0.8299 (0.8299)  loss_giou_aux_0: 1.4249 (1.4249)  loss_vfl_aux_1: 0.3977 (0.3977)  loss_bbox_aux_1: 0.8380 (0.8380)  loss_giou_aux_1: 1.4169 (1.4169)  loss_vfl_dn_0: 0.3193 (0.3193)  loss_bbox_dn_0: 0.5421 (0.5421)  loss_giou_dn_0: 1.3707 (1.3707)  loss_vfl_dn_1: 0.3174 (0.3174)  loss_bbox_dn_1: 0.5405 (0.5405)  loss_giou_dn_1: 1.3666 (1.3666)  loss_vfl_dn_2: 0.3254 (0.3254)  loss_bbox_dn_2: 0.5392 (0.5392)  loss_giou_dn_2: 1.3637 (1.3637)  loss_vfl_enc_0: 0.3296 (0.3296)  loss_bbox_enc_0: 0.8541 (0.8541)  loss_giou_enc_0: 1.4395 (1.4395)  time: 2.4868  data: 1.7727  max mem: 6448
# Epoch: [87]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 16.7482 (16.9690)  loss_vfl: 0.3848 (0.4128)  loss_bbox: 0.7555 (0.7862)  loss_giou: 1.3114 (1.3661)  loss_vfl_aux_0: 0.3518 (0.3685)  loss_bbox_aux_0: 0.7880 (0.8090)  loss_giou_aux_0: 1.3413 (1.3831)  loss_vfl_aux_1: 0.3977 (0.4250)  loss_bbox_aux_1: 0.7721 (0.8051)  loss_giou_aux_1: 1.3185 (1.3677)  loss_vfl_dn_0: 0.3193 (0.3234)  loss_bbox_dn_0: 0.5421 (0.5446)  loss_giou_dn_0: 1.3458 (1.3583)  loss_vfl_dn_1: 0.3174 (0.3240)  loss_bbox_dn_1: 0.5405 (0.5428)  loss_giou_dn_1: 1.3395 (1.3530)  loss_vfl_dn_2: 0.3254 (0.3312)  loss_bbox_dn_2: 0.5392 (0.5411)  loss_giou_dn_2: 1.3327 (1.3482)  loss_vfl_enc_0: 0.3296 (0.3486)  loss_bbox_enc_0: 0.8079 (0.8310)  loss_giou_enc_0: 1.3591 (1.3993)  time: 1.5766  data: 0.8864  max mem: 6448
# Epoch: [87] Total time: 0:00:03 (1.6028 s / it)
# Averaged stats: lr: 0.000009  loss: 16.7482 (16.9690)  loss_vfl: 0.3848 (0.4128)  loss_bbox: 0.7555 (0.7862)  loss_giou: 1.3114 (1.3661)  loss_vfl_aux_0: 0.3518 (0.3685)  loss_bbox_aux_0: 0.7880 (0.8090)  loss_giou_aux_0: 1.3413 (1.3831)  loss_vfl_aux_1: 0.3977 (0.4250)  loss_bbox_aux_1: 0.7721 (0.8051)  loss_giou_aux_1: 1.3185 (1.3677)  loss_vfl_dn_0: 0.3193 (0.3234)  loss_bbox_dn_0: 0.5421 (0.5446)  loss_giou_dn_0: 1.3458 (1.3583)  loss_vfl_dn_1: 0.3174 (0.3240)  loss_bbox_dn_1: 0.5405 (0.5428)  loss_giou_dn_1: 1.3395 (1.3530)  loss_vfl_dn_2: 0.3254 (0.3312)  loss_bbox_dn_2: 0.5392 (0.5411)  loss_giou_dn_2: 1.3327 (1.3482)  loss_vfl_enc_0: 0.3296 (0.3486)  loss_bbox_enc_0: 0.8079 (0.8310)  loss_giou_enc_0: 1.3591 (1.3993)
# Test:  [0/1]  eta: 0:00:00    time: 0.8497  data: 0.4417  max mem: 6448
# Test: Total time: 0:00:00 (0.8976 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 85, 'coco_eval_bbox': 0.01895057111018066}
# Epoch: [88]  [0/2]  eta: 0:00:04  lr: 0.000009  loss: 18.6665 (18.6665)  loss_vfl: 0.4045 (0.4045)  loss_bbox: 1.0155 (1.0155)  loss_giou: 1.4029 (1.4029)  loss_vfl_aux_0: 0.3533 (0.3533)  loss_bbox_aux_0: 1.0979 (1.0979)  loss_giou_aux_0: 1.3949 (1.3949)  loss_vfl_aux_1: 0.4080 (0.4080)  loss_bbox_aux_1: 1.0487 (1.0487)  loss_giou_aux_1: 1.3890 (1.3890)  loss_vfl_dn_0: 0.3364 (0.3364)  loss_bbox_dn_0: 0.7440 (0.7440)  loss_giou_dn_0: 1.3514 (1.3514)  loss_vfl_dn_1: 0.3335 (0.3335)  loss_bbox_dn_1: 0.7420 (0.7420)  loss_giou_dn_1: 1.3471 (1.3471)  loss_vfl_dn_2: 0.3413 (0.3413)  loss_bbox_dn_2: 0.7399 (0.7399)  loss_giou_dn_2: 1.3429 (1.3429)  loss_vfl_enc_0: 0.3481 (0.3481)  loss_bbox_enc_0: 1.1075 (1.1075)  loss_giou_enc_0: 1.4177 (1.4177)  time: 2.3613  data: 1.6527  max mem: 6448
# Epoch: [88]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 16.0971 (17.3818)  loss_vfl: 0.4045 (0.4408)  loss_bbox: 0.6487 (0.8321)  loss_giou: 1.2519 (1.3274)  loss_vfl_aux_0: 0.3533 (0.4008)  loss_bbox_aux_0: 0.6561 (0.8770)  loss_giou_aux_0: 1.2674 (1.3312)  loss_vfl_aux_1: 0.4080 (0.4346)  loss_bbox_aux_1: 0.6768 (0.8627)  loss_giou_aux_1: 1.2620 (1.3255)  loss_vfl_dn_0: 0.3264 (0.3314)  loss_bbox_dn_0: 0.5320 (0.6380)  loss_giou_dn_0: 1.3504 (1.3509)  loss_vfl_dn_1: 0.3269 (0.3302)  loss_bbox_dn_1: 0.5293 (0.6356)  loss_giou_dn_1: 1.3433 (1.3452)  loss_vfl_dn_2: 0.3340 (0.3376)  loss_bbox_dn_2: 0.5268 (0.6333)  loss_giou_dn_2: 1.3365 (1.3397)  loss_vfl_enc_0: 0.3481 (0.3754)  loss_bbox_enc_0: 0.6697 (0.8886)  loss_giou_enc_0: 1.2699 (1.3438)  time: 1.5157  data: 0.8264  max mem: 6448
# Epoch: [88] Total time: 0:00:03 (1.5367 s / it)
# Averaged stats: lr: 0.000009  loss: 16.0971 (17.3818)  loss_vfl: 0.4045 (0.4408)  loss_bbox: 0.6487 (0.8321)  loss_giou: 1.2519 (1.3274)  loss_vfl_aux_0: 0.3533 (0.4008)  loss_bbox_aux_0: 0.6561 (0.8770)  loss_giou_aux_0: 1.2674 (1.3312)  loss_vfl_aux_1: 0.4080 (0.4346)  loss_bbox_aux_1: 0.6768 (0.8627)  loss_giou_aux_1: 1.2620 (1.3255)  loss_vfl_dn_0: 0.3264 (0.3314)  loss_bbox_dn_0: 0.5320 (0.6380)  loss_giou_dn_0: 1.3504 (1.3509)  loss_vfl_dn_1: 0.3269 (0.3302)  loss_bbox_dn_1: 0.5293 (0.6356)  loss_giou_dn_1: 1.3433 (1.3452)  loss_vfl_dn_2: 0.3340 (0.3376)  loss_bbox_dn_2: 0.5268 (0.6333)  loss_giou_dn_2: 1.3365 (1.3397)  loss_vfl_enc_0: 0.3481 (0.3754)  loss_bbox_enc_0: 0.6697 (0.8886)  loss_giou_enc_0: 1.2699 (1.3438)
# Test:  [0/1]  eta: 0:00:00    time: 0.8732  data: 0.4332  max mem: 6448
# Test: Total time: 0:00:00 (0.9184 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 85, 'coco_eval_bbox': 0.01895057111018066}
# Epoch: [89]  [0/2]  eta: 0:00:05  lr: 0.000009  loss: 16.3328 (16.3328)  loss_vfl: 0.3682 (0.3682)  loss_bbox: 0.7095 (0.7095)  loss_giou: 1.4050 (1.4050)  loss_vfl_aux_0: 0.3403 (0.3403)  loss_bbox_aux_0: 0.7276 (0.7276)  loss_giou_aux_0: 1.4045 (1.4045)  loss_vfl_aux_1: 0.3801 (0.3801)  loss_bbox_aux_1: 0.7194 (0.7194)  loss_giou_aux_1: 1.4030 (1.4030)  loss_vfl_dn_0: 0.3086 (0.3086)  loss_bbox_dn_0: 0.4556 (0.4556)  loss_giou_dn_0: 1.3763 (1.3763)  loss_vfl_dn_1: 0.3057 (0.3057)  loss_bbox_dn_1: 0.4537 (0.4537)  loss_giou_dn_1: 1.3703 (1.3703)  loss_vfl_dn_2: 0.3149 (0.3149)  loss_bbox_dn_2: 0.4518 (0.4518)  loss_giou_dn_2: 1.3641 (1.3641)  loss_vfl_enc_0: 0.2842 (0.2842)  loss_bbox_enc_0: 0.7604 (0.7604)  loss_giou_enc_0: 1.4294 (1.4294)  time: 2.7289  data: 2.0123  max mem: 6448
# Epoch: [89]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 16.3328 (16.4346)  loss_vfl: 0.3682 (0.4268)  loss_bbox: 0.7095 (0.7099)  loss_giou: 1.2536 (1.3293)  loss_vfl_aux_0: 0.3403 (0.3923)  loss_bbox_aux_0: 0.7276 (0.7282)  loss_giou_aux_0: 1.2751 (1.3398)  loss_vfl_aux_1: 0.3801 (0.4344)  loss_bbox_aux_1: 0.7194 (0.7204)  loss_giou_aux_1: 1.2615 (1.3323)  loss_vfl_dn_0: 0.3086 (0.3163)  loss_bbox_dn_0: 0.4556 (0.5073)  loss_giou_dn_0: 1.3662 (1.3713)  loss_vfl_dn_1: 0.3057 (0.3136)  loss_bbox_dn_1: 0.4537 (0.5052)  loss_giou_dn_1: 1.3609 (1.3656)  loss_vfl_dn_2: 0.3149 (0.3206)  loss_bbox_dn_2: 0.4518 (0.5032)  loss_giou_dn_2: 1.3553 (1.3597)  loss_vfl_enc_0: 0.2842 (0.3467)  loss_bbox_enc_0: 0.7439 (0.7522)  loss_giou_enc_0: 1.2896 (1.3595)  time: 1.8708  data: 1.0062  max mem: 6448
# Epoch: [89] Total time: 0:00:03 (1.9009 s / it)
# Averaged stats: lr: 0.000009  loss: 16.3328 (16.4346)  loss_vfl: 0.3682 (0.4268)  loss_bbox: 0.7095 (0.7099)  loss_giou: 1.2536 (1.3293)  loss_vfl_aux_0: 0.3403 (0.3923)  loss_bbox_aux_0: 0.7276 (0.7282)  loss_giou_aux_0: 1.2751 (1.3398)  loss_vfl_aux_1: 0.3801 (0.4344)  loss_bbox_aux_1: 0.7194 (0.7204)  loss_giou_aux_1: 1.2615 (1.3323)  loss_vfl_dn_0: 0.3086 (0.3163)  loss_bbox_dn_0: 0.4556 (0.5073)  loss_giou_dn_0: 1.3662 (1.3713)  loss_vfl_dn_1: 0.3057 (0.3136)  loss_bbox_dn_1: 0.4537 (0.5052)  loss_giou_dn_1: 1.3609 (1.3656)  loss_vfl_dn_2: 0.3149 (0.3206)  loss_bbox_dn_2: 0.4518 (0.5032)  loss_giou_dn_2: 1.3553 (1.3597)  loss_vfl_enc_0: 0.2842 (0.3467)  loss_bbox_enc_0: 0.7439 (0.7522)  loss_giou_enc_0: 1.2896 (1.3595)
# Test:  [0/1]  eta: 0:00:00    time: 0.8730  data: 0.4479  max mem: 6448
# Test: Total time: 0:00:00 (0.9078 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 89, 'coco_eval_bbox': 0.024355492076499605}
# Epoch: [90]  [0/2]  eta: 0:00:05  lr: 0.000009  loss: 15.8870 (15.8870)  loss_vfl: 0.4907 (0.4907)  loss_bbox: 0.6245 (0.6245)  loss_giou: 1.2201 (1.2201)  loss_vfl_aux_0: 0.4414 (0.4414)  loss_bbox_aux_0: 0.6395 (0.6395)  loss_giou_aux_0: 1.2326 (1.2326)  loss_vfl_aux_1: 0.4973 (0.4973)  loss_bbox_aux_1: 0.6176 (0.6176)  loss_giou_aux_1: 1.2249 (1.2249)  loss_vfl_dn_0: 0.3064 (0.3064)  loss_bbox_dn_0: 0.5277 (0.5277)  loss_giou_dn_0: 1.3755 (1.3755)  loss_vfl_dn_1: 0.3022 (0.3022)  loss_bbox_dn_1: 0.5251 (0.5251)  loss_giou_dn_1: 1.3670 (1.3670)  loss_vfl_dn_2: 0.3115 (0.3115)  loss_bbox_dn_2: 0.5224 (0.5224)  loss_giou_dn_2: 1.3593 (1.3593)  loss_vfl_enc_0: 0.4019 (0.4019)  loss_bbox_enc_0: 0.6514 (0.6514)  loss_giou_enc_0: 1.2480 (1.2480)  time: 2.6173  data: 1.9050  max mem: 6448
# Epoch: [90]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 15.7227 (15.8049)  loss_vfl: 0.4243 (0.4575)  loss_bbox: 0.6245 (0.6268)  loss_giou: 1.2201 (1.2666)  loss_vfl_aux_0: 0.3833 (0.4124)  loss_bbox_aux_0: 0.6395 (0.6472)  loss_giou_aux_0: 1.2326 (1.2819)  loss_vfl_aux_1: 0.4312 (0.4642)  loss_bbox_aux_1: 0.6176 (0.6266)  loss_giou_aux_1: 1.2249 (1.2692)  loss_vfl_dn_0: 0.3064 (0.3090)  loss_bbox_dn_0: 0.4344 (0.4810)  loss_giou_dn_0: 1.3544 (1.3649)  loss_vfl_dn_1: 0.3022 (0.3076)  loss_bbox_dn_1: 0.4319 (0.4785)  loss_giou_dn_1: 1.3476 (1.3573)  loss_vfl_dn_2: 0.3115 (0.3151)  loss_bbox_dn_2: 0.4295 (0.4760)  loss_giou_dn_2: 1.3411 (1.3502)  loss_vfl_enc_0: 0.3489 (0.3754)  loss_bbox_enc_0: 0.6489 (0.6502)  loss_giou_enc_0: 1.2480 (1.2873)  time: 1.6459  data: 0.9526  max mem: 6448
# Epoch: [90] Total time: 0:00:03 (1.6671 s / it)
# Averaged stats: lr: 0.000009  loss: 15.7227 (15.8049)  loss_vfl: 0.4243 (0.4575)  loss_bbox: 0.6245 (0.6268)  loss_giou: 1.2201 (1.2666)  loss_vfl_aux_0: 0.3833 (0.4124)  loss_bbox_aux_0: 0.6395 (0.6472)  loss_giou_aux_0: 1.2326 (1.2819)  loss_vfl_aux_1: 0.4312 (0.4642)  loss_bbox_aux_1: 0.6176 (0.6266)  loss_giou_aux_1: 1.2249 (1.2692)  loss_vfl_dn_0: 0.3064 (0.3090)  loss_bbox_dn_0: 0.4344 (0.4810)  loss_giou_dn_0: 1.3544 (1.3649)  loss_vfl_dn_1: 0.3022 (0.3076)  loss_bbox_dn_1: 0.4319 (0.4785)  loss_giou_dn_1: 1.3476 (1.3573)  loss_vfl_dn_2: 0.3115 (0.3151)  loss_bbox_dn_2: 0.4295 (0.4760)  loss_giou_dn_2: 1.3411 (1.3502)  loss_vfl_enc_0: 0.3489 (0.3754)  loss_bbox_enc_0: 0.6489 (0.6502)  loss_giou_enc_0: 1.2480 (1.2873)
# Test:  [0/1]  eta: 0:00:00    time: 0.8653  data: 0.4371  max mem: 6448
# Test: Total time: 0:00:00 (0.9060 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 90, 'coco_eval_bbox': 0.024808289962065407}
# Epoch: [91]  [0/2]  eta: 0:00:04  lr: 0.000009  loss: 17.4539 (17.4539)  loss_vfl: 0.3782 (0.3782)  loss_bbox: 0.8889 (0.8889)  loss_giou: 1.3754 (1.3754)  loss_vfl_aux_0: 0.3557 (0.3557)  loss_bbox_aux_0: 0.8983 (0.8983)  loss_giou_aux_0: 1.3818 (1.3818)  loss_vfl_aux_1: 0.3806 (0.3806)  loss_bbox_aux_1: 0.8871 (0.8871)  loss_giou_aux_1: 1.3741 (1.3741)  loss_vfl_dn_0: 0.3301 (0.3301)  loss_bbox_dn_0: 0.6081 (0.6081)  loss_giou_dn_0: 1.3641 (1.3641)  loss_vfl_dn_1: 0.3271 (0.3271)  loss_bbox_dn_1: 0.6058 (0.6058)  loss_giou_dn_1: 1.3589 (1.3589)  loss_vfl_dn_2: 0.3284 (0.3284)  loss_bbox_dn_2: 0.6036 (0.6036)  loss_giou_dn_2: 1.3535 (1.3535)  loss_vfl_enc_0: 0.2974 (0.2974)  loss_bbox_enc_0: 0.9442 (0.9442)  loss_giou_enc_0: 1.4127 (1.4127)  time: 2.4279  data: 1.7179  max mem: 6448
# Epoch: [91]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 17.4539 (17.5813)  loss_vfl: 0.3782 (0.4408)  loss_bbox: 0.8889 (0.8911)  loss_giou: 1.2308 (1.3031)  loss_vfl_aux_0: 0.3557 (0.4099)  loss_bbox_aux_0: 0.8959 (0.8971)  loss_giou_aux_0: 1.2365 (1.3091)  loss_vfl_aux_1: 0.3806 (0.4382)  loss_bbox_aux_1: 0.8871 (0.8969)  loss_giou_aux_1: 1.2452 (1.3097)  loss_vfl_dn_0: 0.3301 (0.3329)  loss_bbox_dn_0: 0.6081 (0.6707)  loss_giou_dn_0: 1.3429 (1.3535)  loss_vfl_dn_1: 0.3271 (0.3326)  loss_bbox_dn_1: 0.6058 (0.6680)  loss_giou_dn_1: 1.3358 (1.3473)  loss_vfl_dn_2: 0.3284 (0.3356)  loss_bbox_dn_2: 0.6036 (0.6654)  loss_giou_dn_2: 1.3287 (1.3411)  loss_vfl_enc_0: 0.2974 (0.3636)  loss_bbox_enc_0: 0.9233 (0.9338)  loss_giou_enc_0: 1.2686 (1.3407)  time: 1.5664  data: 0.8774  max mem: 6448
# Epoch: [91] Total time: 0:00:03 (1.5857 s / it)
# Averaged stats: lr: 0.000009  loss: 17.4539 (17.5813)  loss_vfl: 0.3782 (0.4408)  loss_bbox: 0.8889 (0.8911)  loss_giou: 1.2308 (1.3031)  loss_vfl_aux_0: 0.3557 (0.4099)  loss_bbox_aux_0: 0.8959 (0.8971)  loss_giou_aux_0: 1.2365 (1.3091)  loss_vfl_aux_1: 0.3806 (0.4382)  loss_bbox_aux_1: 0.8871 (0.8969)  loss_giou_aux_1: 1.2452 (1.3097)  loss_vfl_dn_0: 0.3301 (0.3329)  loss_bbox_dn_0: 0.6081 (0.6707)  loss_giou_dn_0: 1.3429 (1.3535)  loss_vfl_dn_1: 0.3271 (0.3326)  loss_bbox_dn_1: 0.6058 (0.6680)  loss_giou_dn_1: 1.3358 (1.3473)  loss_vfl_dn_2: 0.3284 (0.3356)  loss_bbox_dn_2: 0.6036 (0.6654)  loss_giou_dn_2: 1.3287 (1.3411)  loss_vfl_enc_0: 0.2974 (0.3636)  loss_bbox_enc_0: 0.9233 (0.9338)  loss_giou_enc_0: 1.2686 (1.3407)
# Test:  [0/1]  eta: 0:00:00    time: 0.8630  data: 0.4462  max mem: 6448
# Test: Total time: 0:00:00 (0.9099 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 91, 'coco_eval_bbox': 0.02507444167865854}
# Epoch: [92]  [0/2]  eta: 0:00:04  lr: 0.000009  loss: 15.8334 (15.8334)  loss_vfl: 0.4729 (0.4729)  loss_bbox: 0.6063 (0.6063)  loss_giou: 1.2552 (1.2552)  loss_vfl_aux_0: 0.4231 (0.4231)  loss_bbox_aux_0: 0.6358 (0.6358)  loss_giou_aux_0: 1.2698 (1.2698)  loss_vfl_aux_1: 0.4507 (0.4507)  loss_bbox_aux_1: 0.6139 (0.6139)  loss_giou_aux_1: 1.2690 (1.2690)  loss_vfl_dn_0: 0.3083 (0.3083)  loss_bbox_dn_0: 0.5107 (0.5107)  loss_giou_dn_0: 1.3738 (1.3738)  loss_vfl_dn_1: 0.3049 (0.3049)  loss_bbox_dn_1: 0.5074 (0.5074)  loss_giou_dn_1: 1.3653 (1.3653)  loss_vfl_dn_2: 0.3152 (0.3152)  loss_bbox_dn_2: 0.5041 (0.5041)  loss_giou_dn_2: 1.3573 (1.3573)  loss_vfl_enc_0: 0.3762 (0.3762)  loss_bbox_enc_0: 0.6408 (0.6408)  loss_giou_enc_0: 1.2725 (1.2725)  time: 2.4331  data: 1.7075  max mem: 6448
# Epoch: [92]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 15.8334 (16.3552)  loss_vfl: 0.4302 (0.4515)  loss_bbox: 0.6063 (0.6990)  loss_giou: 1.2552 (1.3002)  loss_vfl_aux_0: 0.3799 (0.4015)  loss_bbox_aux_0: 0.6358 (0.7246)  loss_giou_aux_0: 1.2698 (1.3173)  loss_vfl_aux_1: 0.4126 (0.4316)  loss_bbox_aux_1: 0.6139 (0.7032)  loss_giou_aux_1: 1.2690 (1.3115)  loss_vfl_dn_0: 0.3083 (0.3094)  loss_bbox_dn_0: 0.5107 (0.5250)  loss_giou_dn_0: 1.3738 (1.3790)  loss_vfl_dn_1: 0.3037 (0.3043)  loss_bbox_dn_1: 0.5074 (0.5220)  loss_giou_dn_1: 1.3653 (1.3710)  loss_vfl_dn_2: 0.3103 (0.3127)  loss_bbox_dn_2: 0.5041 (0.5191)  loss_giou_dn_2: 1.3573 (1.3638)  loss_vfl_enc_0: 0.3308 (0.3535)  loss_bbox_enc_0: 0.6408 (0.7323)  loss_giou_enc_0: 1.2725 (1.3224)  time: 1.5651  data: 0.8716  max mem: 6448
# Epoch: [92] Total time: 0:00:03 (1.5889 s / it)
# Averaged stats: lr: 0.000009  loss: 15.8334 (16.3552)  loss_vfl: 0.4302 (0.4515)  loss_bbox: 0.6063 (0.6990)  loss_giou: 1.2552 (1.3002)  loss_vfl_aux_0: 0.3799 (0.4015)  loss_bbox_aux_0: 0.6358 (0.7246)  loss_giou_aux_0: 1.2698 (1.3173)  loss_vfl_aux_1: 0.4126 (0.4316)  loss_bbox_aux_1: 0.6139 (0.7032)  loss_giou_aux_1: 1.2690 (1.3115)  loss_vfl_dn_0: 0.3083 (0.3094)  loss_bbox_dn_0: 0.5107 (0.5250)  loss_giou_dn_0: 1.3738 (1.3790)  loss_vfl_dn_1: 0.3037 (0.3043)  loss_bbox_dn_1: 0.5074 (0.5220)  loss_giou_dn_1: 1.3653 (1.3710)  loss_vfl_dn_2: 0.3103 (0.3127)  loss_bbox_dn_2: 0.5041 (0.5191)  loss_giou_dn_2: 1.3573 (1.3638)  loss_vfl_enc_0: 0.3308 (0.3535)  loss_bbox_enc_0: 0.6408 (0.7323)  loss_giou_enc_0: 1.2725 (1.3224)
# Test:  [0/1]  eta: 0:00:00    time: 0.8737  data: 0.4497  max mem: 6448
# Test: Total time: 0:00:00 (0.9208 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 92, 'coco_eval_bbox': 0.025854910293262656}
# Epoch: [93]  [0/2]  eta: 0:00:05  lr: 0.000009  loss: 17.0000 (17.0000)  loss_vfl: 0.4670 (0.4670)  loss_bbox: 0.7800 (0.7800)  loss_giou: 1.2880 (1.2880)  loss_vfl_aux_0: 0.4016 (0.4016)  loss_bbox_aux_0: 0.8033 (0.8033)  loss_giou_aux_0: 1.3028 (1.3028)  loss_vfl_aux_1: 0.4387 (0.4387)  loss_bbox_aux_1: 0.7991 (0.7991)  loss_giou_aux_1: 1.2996 (1.2996)  loss_vfl_dn_0: 0.3162 (0.3162)  loss_bbox_dn_0: 0.6256 (0.6256)  loss_giou_dn_0: 1.3727 (1.3727)  loss_vfl_dn_1: 0.3127 (0.3127)  loss_bbox_dn_1: 0.6224 (0.6224)  loss_giou_dn_1: 1.3658 (1.3658)  loss_vfl_dn_2: 0.3152 (0.3152)  loss_bbox_dn_2: 0.6193 (0.6193)  loss_giou_dn_2: 1.3591 (1.3591)  loss_vfl_enc_0: 0.3723 (0.3723)  loss_bbox_enc_0: 0.8229 (0.8229)  loss_giou_enc_0: 1.3157 (1.3157)  time: 2.5254  data: 1.8042  max mem: 6448
# Epoch: [93]  [1/2]  eta: 0:00:01  lr: 0.000009  loss: 15.7933 (16.3967)  loss_vfl: 0.4443 (0.4557)  loss_bbox: 0.6247 (0.7024)  loss_giou: 1.2880 (1.3041)  loss_vfl_aux_0: 0.3972 (0.3994)  loss_bbox_aux_0: 0.6377 (0.7205)  loss_giou_aux_0: 1.3028 (1.3155)  loss_vfl_aux_1: 0.4211 (0.4299)  loss_bbox_aux_1: 0.6366 (0.7178)  loss_giou_aux_1: 1.2996 (1.3080)  loss_vfl_dn_0: 0.3162 (0.3163)  loss_bbox_dn_0: 0.4632 (0.5444)  loss_giou_dn_0: 1.3446 (1.3586)  loss_vfl_dn_1: 0.3127 (0.3143)  loss_bbox_dn_1: 0.4599 (0.5412)  loss_giou_dn_1: 1.3358 (1.3508)  loss_vfl_dn_2: 0.3152 (0.3187)  loss_bbox_dn_2: 0.4568 (0.5380)  loss_giou_dn_2: 1.3278 (1.3435)  loss_vfl_enc_0: 0.3274 (0.3499)  loss_bbox_enc_0: 0.6517 (0.7373)  loss_giou_enc_0: 1.3157 (1.3304)  time: 1.5984  data: 0.9022  max mem: 6448
# Epoch: [93] Total time: 0:00:03 (1.6222 s / it)
# Averaged stats: lr: 0.000009  loss: 15.7933 (16.3967)  loss_vfl: 0.4443 (0.4557)  loss_bbox: 0.6247 (0.7024)  loss_giou: 1.2880 (1.3041)  loss_vfl_aux_0: 0.3972 (0.3994)  loss_bbox_aux_0: 0.6377 (0.7205)  loss_giou_aux_0: 1.3028 (1.3155)  loss_vfl_aux_1: 0.4211 (0.4299)  loss_bbox_aux_1: 0.6366 (0.7178)  loss_giou_aux_1: 1.2996 (1.3080)  loss_vfl_dn_0: 0.3162 (0.3163)  loss_bbox_dn_0: 0.4632 (0.5444)  loss_giou_dn_0: 1.3446 (1.3586)  loss_vfl_dn_1: 0.3127 (0.3143)  loss_bbox_dn_1: 0.4599 (0.5412)  loss_giou_dn_1: 1.3358 (1.3508)  loss_vfl_dn_2: 0.3152 (0.3187)  loss_bbox_dn_2: 0.4568 (0.5380)  loss_giou_dn_2: 1.3278 (1.3435)  loss_vfl_enc_0: 0.3274 (0.3499)  loss_bbox_enc_0: 0.6517 (0.7373)  loss_giou_enc_0: 1.3157 (1.3304)
# Test:  [0/1]  eta: 0:00:00    time: 0.8383  data: 0.4321  max mem: 6448
# Test: Total time: 0:00:00 (0.8742 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 93, 'coco_eval_bbox': 0.02650462608385869}
# Epoch: [94]  [0/2]  eta: 0:00:04  lr: 0.000010  loss: 17.1253 (17.1253)  loss_vfl: 0.4375 (0.4375)  loss_bbox: 0.8411 (0.8411)  loss_giou: 1.3476 (1.3476)  loss_vfl_aux_0: 0.3799 (0.3799)  loss_bbox_aux_0: 0.8403 (0.8403)  loss_giou_aux_0: 1.3590 (1.3590)  loss_vfl_aux_1: 0.4102 (0.4102)  loss_bbox_aux_1: 0.8378 (0.8378)  loss_giou_aux_1: 1.3478 (1.3478)  loss_vfl_dn_0: 0.3298 (0.3298)  loss_bbox_dn_0: 0.5754 (0.5754)  loss_giou_dn_0: 1.3504 (1.3504)  loss_vfl_dn_1: 0.3242 (0.3242)  loss_bbox_dn_1: 0.5724 (0.5724)  loss_giou_dn_1: 1.3420 (1.3420)  loss_vfl_dn_2: 0.3315 (0.3315)  loss_bbox_dn_2: 0.5696 (0.5696)  loss_giou_dn_2: 1.3352 (1.3352)  loss_vfl_enc_0: 0.3267 (0.3267)  loss_bbox_enc_0: 0.8774 (0.8774)  loss_giou_enc_0: 1.3895 (1.3895)  time: 2.4815  data: 1.7683  max mem: 6448
# Epoch: [94]  [1/2]  eta: 0:00:01  lr: 0.000010  loss: 16.3733 (16.7493)  loss_vfl: 0.4097 (0.4236)  loss_bbox: 0.6979 (0.7695)  loss_giou: 1.3476 (1.3604)  loss_vfl_aux_0: 0.3647 (0.3723)  loss_bbox_aux_0: 0.7229 (0.7816)  loss_giou_aux_0: 1.3590 (1.3767)  loss_vfl_aux_1: 0.3770 (0.3936)  loss_bbox_aux_1: 0.6967 (0.7672)  loss_giou_aux_1: 1.3478 (1.3721)  loss_vfl_dn_0: 0.3057 (0.3177)  loss_bbox_dn_0: 0.5042 (0.5398)  loss_giou_dn_0: 1.3504 (1.3589)  loss_vfl_dn_1: 0.3069 (0.3156)  loss_bbox_dn_1: 0.5005 (0.5364)  loss_giou_dn_1: 1.3420 (1.3500)  loss_vfl_dn_2: 0.3142 (0.3229)  loss_bbox_dn_2: 0.4969 (0.5333)  loss_giou_dn_2: 1.3352 (1.3424)  loss_vfl_enc_0: 0.3267 (0.3274)  loss_bbox_enc_0: 0.7157 (0.7966)  loss_giou_enc_0: 1.3895 (1.3914)  time: 1.5769  data: 0.8842  max mem: 6448
# Epoch: [94] Total time: 0:00:03 (1.6023 s / it)
# Averaged stats: lr: 0.000010  loss: 16.3733 (16.7493)  loss_vfl: 0.4097 (0.4236)  loss_bbox: 0.6979 (0.7695)  loss_giou: 1.3476 (1.3604)  loss_vfl_aux_0: 0.3647 (0.3723)  loss_bbox_aux_0: 0.7229 (0.7816)  loss_giou_aux_0: 1.3590 (1.3767)  loss_vfl_aux_1: 0.3770 (0.3936)  loss_bbox_aux_1: 0.6967 (0.7672)  loss_giou_aux_1: 1.3478 (1.3721)  loss_vfl_dn_0: 0.3057 (0.3177)  loss_bbox_dn_0: 0.5042 (0.5398)  loss_giou_dn_0: 1.3504 (1.3589)  loss_vfl_dn_1: 0.3069 (0.3156)  loss_bbox_dn_1: 0.5005 (0.5364)  loss_giou_dn_1: 1.3420 (1.3500)  loss_vfl_dn_2: 0.3142 (0.3229)  loss_bbox_dn_2: 0.4969 (0.5333)  loss_giou_dn_2: 1.3352 (1.3424)  loss_vfl_enc_0: 0.3267 (0.3274)  loss_bbox_enc_0: 0.7157 (0.7966)  loss_giou_enc_0: 1.3895 (1.3914)
# Test:  [0/1]  eta: 0:00:00    time: 0.8629  data: 0.4305  max mem: 6448
# Test: Total time: 0:00:00 (0.8957 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 94, 'coco_eval_bbox': 0.029374851445599755}
# Epoch: [95]  [0/2]  eta: 0:00:05  lr: 0.000010  loss: 16.4770 (16.4770)  loss_vfl: 0.4429 (0.4429)  loss_bbox: 0.7181 (0.7181)  loss_giou: 1.3232 (1.3232)  loss_vfl_aux_0: 0.3911 (0.3911)  loss_bbox_aux_0: 0.7278 (0.7278)  loss_giou_aux_0: 1.3352 (1.3352)  loss_vfl_aux_1: 0.4104 (0.4104)  loss_bbox_aux_1: 0.7416 (0.7416)  loss_giou_aux_1: 1.3272 (1.3272)  loss_vfl_dn_0: 0.3208 (0.3208)  loss_bbox_dn_0: 0.5490 (0.5490)  loss_giou_dn_0: 1.3606 (1.3606)  loss_vfl_dn_1: 0.3140 (0.3140)  loss_bbox_dn_1: 0.5452 (0.5452)  loss_giou_dn_1: 1.3511 (1.3511)  loss_vfl_dn_2: 0.3225 (0.3225)  loss_bbox_dn_2: 0.5415 (0.5415)  loss_giou_dn_2: 1.3432 (1.3432)  loss_vfl_enc_0: 0.3264 (0.3264)  loss_bbox_enc_0: 0.7371 (0.7371)  loss_giou_enc_0: 1.3482 (1.3482)  time: 2.5613  data: 1.8462  max mem: 6448
# Epoch: [95]  [1/2]  eta: 0:00:01  lr: 0.000010  loss: 16.2327 (16.3549)  loss_vfl: 0.4429 (0.4449)  loss_bbox: 0.7047 (0.7114)  loss_giou: 1.3004 (1.3118)  loss_vfl_aux_0: 0.3911 (0.4032)  loss_bbox_aux_0: 0.7168 (0.7223)  loss_giou_aux_0: 1.3126 (1.3239)  loss_vfl_aux_1: 0.4104 (0.4233)  loss_bbox_aux_1: 0.7238 (0.7327)  loss_giou_aux_1: 1.3023 (1.3148)  loss_vfl_dn_0: 0.3191 (0.3199)  loss_bbox_dn_0: 0.5017 (0.5254)  loss_giou_dn_0: 1.3596 (1.3601)  loss_vfl_dn_1: 0.3132 (0.3136)  loss_bbox_dn_1: 0.4983 (0.5217)  loss_giou_dn_1: 1.3498 (1.3504)  loss_vfl_dn_2: 0.3171 (0.3198)  loss_bbox_dn_2: 0.4950 (0.5182)  loss_giou_dn_2: 1.3412 (1.3422)  loss_vfl_enc_0: 0.3264 (0.3312)  loss_bbox_enc_0: 0.7201 (0.7286)  loss_giou_enc_0: 1.3223 (1.3353)  time: 1.6315  data: 0.9412  max mem: 6448
# Epoch: [95] Total time: 0:00:03 (1.6547 s / it)
# Averaged stats: lr: 0.000010  loss: 16.2327 (16.3549)  loss_vfl: 0.4429 (0.4449)  loss_bbox: 0.7047 (0.7114)  loss_giou: 1.3004 (1.3118)  loss_vfl_aux_0: 0.3911 (0.4032)  loss_bbox_aux_0: 0.7168 (0.7223)  loss_giou_aux_0: 1.3126 (1.3239)  loss_vfl_aux_1: 0.4104 (0.4233)  loss_bbox_aux_1: 0.7238 (0.7327)  loss_giou_aux_1: 1.3023 (1.3148)  loss_vfl_dn_0: 0.3191 (0.3199)  loss_bbox_dn_0: 0.5017 (0.5254)  loss_giou_dn_0: 1.3596 (1.3601)  loss_vfl_dn_1: 0.3132 (0.3136)  loss_bbox_dn_1: 0.4983 (0.5217)  loss_giou_dn_1: 1.3498 (1.3504)  loss_vfl_dn_2: 0.3171 (0.3198)  loss_bbox_dn_2: 0.4950 (0.5182)  loss_giou_dn_2: 1.3412 (1.3422)  loss_vfl_enc_0: 0.3264 (0.3312)  loss_bbox_enc_0: 0.7201 (0.7286)  loss_giou_enc_0: 1.3223 (1.3353)
# Test:  [0/1]  eta: 0:00:00    time: 0.8615  data: 0.4340  max mem: 6448
# Test: Total time: 0:00:00 (0.8961 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# best_stat: {'epoch': 95, 'coco_eval_bbox': 0.0310872970938235}
# ...
# Test:  [0/1]  eta: 0:00:00    time: 0.8519  data: 0.4631  max mem: 6448
# Test: Total time: 0:00:00 (0.8882 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.725
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.717
# best_stat: {'epoch': 260, 'coco_eval_bbox': 0.341654151755621}
# Epoch: [296]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 5.9430 (5.9430)  loss_vfl: 0.3091 (0.3091)  loss_bbox: 0.0490 (0.0490)  loss_giou: 0.1470 (0.1470)  loss_vfl_aux_0: 0.4412 (0.4412)  loss_bbox_aux_0: 0.0674 (0.0674)  loss_giou_aux_0: 0.2185 (0.2185)  loss_vfl_aux_1: 0.3450 (0.3450)  loss_bbox_aux_1: 0.0523 (0.0523)  loss_giou_aux_1: 0.1582 (0.1582)  loss_vfl_dn_0: 0.4419 (0.4419)  loss_bbox_dn_0: 0.2914 (0.2914)  loss_giou_dn_0: 0.7136 (0.7136)  loss_vfl_dn_1: 0.4001 (0.4001)  loss_bbox_dn_1: 0.1701 (0.1701)  loss_giou_dn_1: 0.4336 (0.4336)  loss_vfl_dn_2: 0.3833 (0.3833)  loss_bbox_dn_2: 0.1243 (0.1243)  loss_giou_dn_2: 0.3257 (0.3257)  loss_vfl_enc_0: 0.4160 (0.4160)  loss_bbox_enc_0: 0.1146 (0.1146)  loss_giou_enc_0: 0.3408 (0.3408)  time: 1.4247  data: 0.7432  max mem: 6448
# Epoch: [296]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 5.9430 (6.1853)  loss_vfl: 0.3091 (0.3217)  loss_bbox: 0.0490 (0.0605)  loss_giou: 0.1470 (0.1772)  loss_vfl_aux_0: 0.4412 (0.4457)  loss_bbox_aux_0: 0.0674 (0.0815)  loss_giou_aux_0: 0.2185 (0.2503)  loss_vfl_aux_1: 0.3450 (0.3545)  loss_bbox_aux_1: 0.0523 (0.0648)  loss_giou_aux_1: 0.1582 (0.1905)  loss_vfl_dn_0: 0.4260 (0.4340)  loss_bbox_dn_0: 0.2914 (0.3037)  loss_giou_dn_0: 0.7136 (0.7164)  loss_vfl_dn_1: 0.3921 (0.3961)  loss_bbox_dn_1: 0.1701 (0.1768)  loss_giou_dn_1: 0.4336 (0.4389)  loss_vfl_dn_2: 0.3708 (0.3771)  loss_bbox_dn_2: 0.1243 (0.1270)  loss_giou_dn_2: 0.3257 (0.3274)  loss_vfl_enc_0: 0.4160 (0.4249)  loss_bbox_enc_0: 0.1146 (0.1370)  loss_giou_enc_0: 0.3408 (0.3793)  time: 1.0768  data: 0.3910  max mem: 6448
# Epoch: [296] Total time: 0:00:02 (1.1029 s / it)
# Averaged stats: lr: 0.000030  loss: 5.9430 (6.1853)  loss_vfl: 0.3091 (0.3217)  loss_bbox: 0.0490 (0.0605)  loss_giou: 0.1470 (0.1772)  loss_vfl_aux_0: 0.4412 (0.4457)  loss_bbox_aux_0: 0.0674 (0.0815)  loss_giou_aux_0: 0.2185 (0.2503)  loss_vfl_aux_1: 0.3450 (0.3545)  loss_bbox_aux_1: 0.0523 (0.0648)  loss_giou_aux_1: 0.1582 (0.1905)  loss_vfl_dn_0: 0.4260 (0.4340)  loss_bbox_dn_0: 0.2914 (0.3037)  loss_giou_dn_0: 0.7136 (0.7164)  loss_vfl_dn_1: 0.3921 (0.3961)  loss_bbox_dn_1: 0.1701 (0.1768)  loss_giou_dn_1: 0.4336 (0.4389)  loss_vfl_dn_2: 0.3708 (0.3771)  loss_bbox_dn_2: 0.1243 (0.1270)  loss_giou_dn_2: 0.3257 (0.3274)  loss_vfl_enc_0: 0.4160 (0.4249)  loss_bbox_enc_0: 0.1146 (0.1370)  loss_giou_enc_0: 0.3408 (0.3793)
# Test:  [0/1]  eta: 0:00:00    time: 0.9220  data: 0.4756  max mem: 6448
# Test: Total time: 0:00:00 (0.9767 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.723
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.730
# best_stat: {'epoch': 260, 'coco_eval_bbox': 0.341654151755621}
# Epoch: [297]  [0/2]  eta: 0:00:03  lr: 0.000030  loss: 5.7873 (5.7873)  loss_vfl: 0.2817 (0.2817)  loss_bbox: 0.0486 (0.0486)  loss_giou: 0.1636 (0.1636)  loss_vfl_aux_0: 0.4202 (0.4202)  loss_bbox_aux_0: 0.0678 (0.0678)  loss_giou_aux_0: 0.2148 (0.2148)  loss_vfl_aux_1: 0.3096 (0.3096)  loss_bbox_aux_1: 0.0525 (0.0525)  loss_giou_aux_1: 0.1727 (0.1727)  loss_vfl_dn_0: 0.4272 (0.4272)  loss_bbox_dn_0: 0.2904 (0.2904)  loss_giou_dn_0: 0.7154 (0.7154)  loss_vfl_dn_1: 0.3777 (0.3777)  loss_bbox_dn_1: 0.1695 (0.1695)  loss_giou_dn_1: 0.4276 (0.4276)  loss_vfl_dn_2: 0.3545 (0.3545)  loss_bbox_dn_2: 0.1215 (0.1215)  loss_giou_dn_2: 0.3121 (0.3121)  loss_vfl_enc_0: 0.4124 (0.4124)  loss_bbox_enc_0: 0.1129 (0.1129)  loss_giou_enc_0: 0.3346 (0.3346)  time: 1.7447  data: 1.0699  max mem: 6448
# Epoch: [297]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 5.7873 (5.9131)  loss_vfl: 0.2817 (0.2914)  loss_bbox: 0.0450 (0.0468)  loss_giou: 0.1418 (0.1527)  loss_vfl_aux_0: 0.4202 (0.4241)  loss_bbox_aux_0: 0.0678 (0.0691)  loss_giou_aux_0: 0.2148 (0.2254)  loss_vfl_aux_1: 0.3096 (0.3193)  loss_bbox_aux_1: 0.0474 (0.0499)  loss_giou_aux_1: 0.1559 (0.1643)  loss_vfl_dn_0: 0.4272 (0.4335)  loss_bbox_dn_0: 0.2904 (0.2957)  loss_giou_dn_0: 0.7154 (0.7250)  loss_vfl_dn_1: 0.3777 (0.3890)  loss_bbox_dn_1: 0.1695 (0.1701)  loss_giou_dn_1: 0.4276 (0.4350)  loss_vfl_dn_2: 0.3545 (0.3634)  loss_bbox_dn_2: 0.1172 (0.1194)  loss_giou_dn_2: 0.3121 (0.3157)  loss_vfl_enc_0: 0.4124 (0.4147)  loss_bbox_enc_0: 0.1129 (0.1279)  loss_giou_enc_0: 0.3346 (0.3808)  time: 1.2173  data: 0.5350  max mem: 6448
# Epoch: [297] Total time: 0:00:02 (1.2424 s / it)
# Averaged stats: lr: 0.000030  loss: 5.7873 (5.9131)  loss_vfl: 0.2817 (0.2914)  loss_bbox: 0.0450 (0.0468)  loss_giou: 0.1418 (0.1527)  loss_vfl_aux_0: 0.4202 (0.4241)  loss_bbox_aux_0: 0.0678 (0.0691)  loss_giou_aux_0: 0.2148 (0.2254)  loss_vfl_aux_1: 0.3096 (0.3193)  loss_bbox_aux_1: 0.0474 (0.0499)  loss_giou_aux_1: 0.1559 (0.1643)  loss_vfl_dn_0: 0.4272 (0.4335)  loss_bbox_dn_0: 0.2904 (0.2957)  loss_giou_dn_0: 0.7154 (0.7250)  loss_vfl_dn_1: 0.3777 (0.3890)  loss_bbox_dn_1: 0.1695 (0.1701)  loss_giou_dn_1: 0.4276 (0.4350)  loss_vfl_dn_2: 0.3545 (0.3634)  loss_bbox_dn_2: 0.1172 (0.1194)  loss_giou_dn_2: 0.3121 (0.3157)  loss_vfl_enc_0: 0.4124 (0.4147)  loss_bbox_enc_0: 0.1129 (0.1279)  loss_giou_enc_0: 0.3346 (0.3808)
# Test:  [0/1]  eta: 0:00:01    time: 1.2260  data: 0.4566  max mem: 6448
# Test: Total time: 0:00:01 (1.2786 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.715
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.726
# best_stat: {'epoch': 260, 'coco_eval_bbox': 0.341654151755621}
# Epoch: [298]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 5.9025 (5.9025)  loss_vfl: 0.2898 (0.2898)  loss_bbox: 0.0499 (0.0499)  loss_giou: 0.1507 (0.1507)  loss_vfl_aux_0: 0.4202 (0.4202)  loss_bbox_aux_0: 0.0621 (0.0621)  loss_giou_aux_0: 0.2040 (0.2040)  loss_vfl_aux_1: 0.3271 (0.3271)  loss_bbox_aux_1: 0.0534 (0.0534)  loss_giou_aux_1: 0.1629 (0.1629)  loss_vfl_dn_0: 0.4392 (0.4392)  loss_bbox_dn_0: 0.3223 (0.3223)  loss_giou_dn_0: 0.7190 (0.7190)  loss_vfl_dn_1: 0.3906 (0.3906)  loss_bbox_dn_1: 0.1865 (0.1865)  loss_giou_dn_1: 0.4307 (0.4307)  loss_vfl_dn_2: 0.3679 (0.3679)  loss_bbox_dn_2: 0.1332 (0.1332)  loss_giou_dn_2: 0.3174 (0.3174)  loss_vfl_enc_0: 0.4141 (0.4141)  loss_bbox_enc_0: 0.1193 (0.1193)  loss_giou_enc_0: 0.3422 (0.3422)  time: 1.3852  data: 0.7024  max mem: 6448
# Epoch: [298]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 5.9025 (5.9853)  loss_vfl: 0.2898 (0.3019)  loss_bbox: 0.0499 (0.0543)  loss_giou: 0.1507 (0.1645)  loss_vfl_aux_0: 0.4202 (0.4258)  loss_bbox_aux_0: 0.0621 (0.0727)  loss_giou_aux_0: 0.2040 (0.2310)  loss_vfl_aux_1: 0.3271 (0.3346)  loss_bbox_aux_1: 0.0534 (0.0601)  loss_giou_aux_1: 0.1629 (0.1789)  loss_vfl_dn_0: 0.4392 (0.4418)  loss_bbox_dn_0: 0.2787 (0.3005)  loss_giou_dn_0: 0.7047 (0.7118)  loss_vfl_dn_1: 0.3906 (0.4000)  loss_bbox_dn_1: 0.1528 (0.1697)  loss_giou_dn_1: 0.4116 (0.4211)  loss_vfl_dn_2: 0.3679 (0.3793)  loss_bbox_dn_2: 0.1101 (0.1216)  loss_giou_dn_2: 0.3039 (0.3106)  loss_vfl_enc_0: 0.4141 (0.4170)  loss_bbox_enc_0: 0.1193 (0.1253)  loss_giou_enc_0: 0.3422 (0.3630)  time: 1.0569  data: 0.3719  max mem: 6448
# Epoch: [298] Total time: 0:00:02 (1.0844 s / it)
# Averaged stats: lr: 0.000030  loss: 5.9025 (5.9853)  loss_vfl: 0.2898 (0.3019)  loss_bbox: 0.0499 (0.0543)  loss_giou: 0.1507 (0.1645)  loss_vfl_aux_0: 0.4202 (0.4258)  loss_bbox_aux_0: 0.0621 (0.0727)  loss_giou_aux_0: 0.2040 (0.2310)  loss_vfl_aux_1: 0.3271 (0.3346)  loss_bbox_aux_1: 0.0534 (0.0601)  loss_giou_aux_1: 0.1629 (0.1789)  loss_vfl_dn_0: 0.4392 (0.4418)  loss_bbox_dn_0: 0.2787 (0.3005)  loss_giou_dn_0: 0.7047 (0.7118)  loss_vfl_dn_1: 0.3906 (0.4000)  loss_bbox_dn_1: 0.1528 (0.1697)  loss_giou_dn_1: 0.4116 (0.4211)  loss_vfl_dn_2: 0.3679 (0.3793)  loss_bbox_dn_2: 0.1101 (0.1216)  loss_giou_dn_2: 0.3039 (0.3106)  loss_vfl_enc_0: 0.4141 (0.4170)  loss_bbox_enc_0: 0.1193 (0.1253)  loss_giou_enc_0: 0.3422 (0.3630)
# Test:  [0/1]  eta: 0:00:00    time: 0.8384  data: 0.4527  max mem: 6448
# Test: Total time: 0:00:00 (0.8870 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.469
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
# best_stat: {'epoch': 260, 'coco_eval_bbox': 0.341654151755621}
# Epoch: [299]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 6.0635 (6.0635)  loss_vfl: 0.3132 (0.3132)  loss_bbox: 0.0579 (0.0579)  loss_giou: 0.1766 (0.1766)  loss_vfl_aux_0: 0.4331 (0.4331)  loss_bbox_aux_0: 0.0833 (0.0833)  loss_giou_aux_0: 0.2539 (0.2539)  loss_vfl_aux_1: 0.3425 (0.3425)  loss_bbox_aux_1: 0.0636 (0.0636)  loss_giou_aux_1: 0.1937 (0.1937)  loss_vfl_dn_0: 0.4417 (0.4417)  loss_bbox_dn_0: 0.2761 (0.2761)  loss_giou_dn_0: 0.7148 (0.7148)  loss_vfl_dn_1: 0.3994 (0.3994)  loss_bbox_dn_1: 0.1577 (0.1577)  loss_giou_dn_1: 0.4306 (0.4306)  loss_vfl_dn_2: 0.3809 (0.3809)  loss_bbox_dn_2: 0.1155 (0.1155)  loss_giou_dn_2: 0.3164 (0.3164)  loss_vfl_enc_0: 0.4148 (0.4148)  loss_bbox_enc_0: 0.1221 (0.1221)  loss_giou_enc_0: 0.3757 (0.3757)  time: 1.4806  data: 0.7913  max mem: 6448
# Epoch: [299]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 6.0635 (6.0861)  loss_vfl: 0.3132 (0.3224)  loss_bbox: 0.0579 (0.0587)  loss_giou: 0.1736 (0.1751)  loss_vfl_aux_0: 0.4331 (0.4349)  loss_bbox_aux_0: 0.0823 (0.0828)  loss_giou_aux_0: 0.2434 (0.2486)  loss_vfl_aux_1: 0.3425 (0.3499)  loss_bbox_aux_1: 0.0636 (0.0652)  loss_giou_aux_1: 0.1937 (0.1965)  loss_vfl_dn_0: 0.4382 (0.4399)  loss_bbox_dn_0: 0.2761 (0.2870)  loss_giou_dn_0: 0.6922 (0.7035)  loss_vfl_dn_1: 0.3884 (0.3939)  loss_bbox_dn_1: 0.1577 (0.1630)  loss_giou_dn_1: 0.4135 (0.4220)  loss_vfl_dn_2: 0.3665 (0.3737)  loss_bbox_dn_2: 0.1155 (0.1183)  loss_giou_dn_2: 0.3066 (0.3115)  loss_vfl_enc_0: 0.4148 (0.4177)  loss_bbox_enc_0: 0.1221 (0.1341)  loss_giou_enc_0: 0.3757 (0.3873)  time: 1.0887  data: 0.3957  max mem: 6448
# Epoch: [299] Total time: 0:00:02 (1.1208 s / it)
# Averaged stats: lr: 0.000030  loss: 6.0635 (6.0861)  loss_vfl: 0.3132 (0.3224)  loss_bbox: 0.0579 (0.0587)  loss_giou: 0.1736 (0.1751)  loss_vfl_aux_0: 0.4331 (0.4349)  loss_bbox_aux_0: 0.0823 (0.0828)  loss_giou_aux_0: 0.2434 (0.2486)  loss_vfl_aux_1: 0.3425 (0.3499)  loss_bbox_aux_1: 0.0636 (0.0652)  loss_giou_aux_1: 0.1937 (0.1965)  loss_vfl_dn_0: 0.4382 (0.4399)  loss_bbox_dn_0: 0.2761 (0.2870)  loss_giou_dn_0: 0.6922 (0.7035)  loss_vfl_dn_1: 0.3884 (0.3939)  loss_bbox_dn_1: 0.1577 (0.1630)  loss_giou_dn_1: 0.4135 (0.4220)  loss_vfl_dn_2: 0.3665 (0.3737)  loss_bbox_dn_2: 0.1155 (0.1183)  loss_giou_dn_2: 0.3066 (0.3115)  loss_vfl_enc_0: 0.4148 (0.4177)  loss_bbox_enc_0: 0.1221 (0.1341)  loss_giou_enc_0: 0.3757 (0.3873)
# Test:  [0/1]  eta: 0:00:00    time: 0.8581  data: 0.4422  max mem: 6448
# Test: Total time: 0:00:00 (0.8924 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
# best_stat: {'epoch': 260, 'coco_eval_bbox': 0.341654151755621}
# Training time 0:27:20

# %% [markdown]
# # ONNX出力

# %%
# !python tools/export_onnx.py \
    -c my_rtdetrv2_r18vd.yml \
    -r output/my_rtdetrv2_r18vd/best.pth \
    --output_file my_rtdetrv2_r18vd.onnx \
    --check
# Out:
# 2024-10-12 04:03:54.798234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-12 04:03:54.821674: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-12 04:03:54.828517: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-12 04:03:54.845144: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-12 04:03:56.297516: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/RT-DETR/rtdetrv2_pytorch/tools/export_onnx.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(args.resume, map_location='cpu')
# Load PResNet18 state_dict
# /content/RT-DETR/rtdetrv2_pytorch/tools/../src/zoo/rtdetr/rtdetrv2_decoder.py:141: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if reference_points.shape[-1] == 2:
# /content/RT-DETR/rtdetrv2_pytorch/tools/../src/zoo/rtdetr/rtdetrv2_decoder.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   elif reference_points.shape[-1] == 4:
# Check export onnx model done...

# %%
# !onnxsim my_rtdetrv2_r18vd.onnx my_rtdetrv2_r18vd.onnx
# Out:
# Your model contains "Tile" ops or/and "ConstantOfShape" ops. Folding these ops can make the
# simplified model much larger. If it is not expected, please specify "--no-large-tensor" (which will
# lose some optimization chances)
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                 ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add             │ 126            │ 117              │
# │ AveragePool     │ 3              │ 3                │
# │ Cast            │ 11             │ 1                │
# │ Clip            │ 9              │ 9                │
# │ Concat          │ 75             │ 32               │
# │ Constant        │ 683            │ 293              │
# │ ConstantOfShape │ 4              │ 0                │
# │ Conv            │ 57             │ 57               │
# │ Div             │ 21             │ 16               │
# │ Erf             │ 1              │ 1                │
# │ Expand          │ 4              │ 0                │
# │ Flatten         │ 1              │ 1                │
# │ Gather          │ 56             │ 17               │
# │ GatherElements  │ 3              │ 3                │
# │ Gemm            │ 4              │ 4                │
# │ GridSample      │ 9              │ 9                │
# │ Identity        │ 6              │ 0                │
# │ Log             │ 3              │ 3                │
# │ MatMul          │ 61             │ 61               │
# │ MaxPool         │ 1              │ 1                │
# │ Mul             │ 82             │ 72               │
# │ Pow             │ 12             │ 12               │
# │ ReduceMax       │ 1              │ 1                │
# │ ReduceMean      │ 24             │ 24               │
# │ ReduceSum       │ 3              │ 3                │
# │ Relu            │ 33             │ 33               │
# │ Reshape         │ 58             │ 55               │
# │ Resize          │ 2              │ 2                │
# │ Shape           │ 67             │ 16               │
# │ Sigmoid         │ 33             │ 33               │
# │ Slice           │ 31             │ 22               │
# │ Softmax         │ 7              │ 7                │
# │ Split           │ 4              │ 4                │
# │ Sqrt            │ 12             │ 12               │
# │ Squeeze         │ 4              │ 4                │
# │ Sub             │ 21             │ 21               │
# │ Tile            │ 4              │ 4                │
# │ TopK            │ 2              │ 2                │
# │ Transpose       │ 45             │ 45               │
# │ Unsqueeze       │ 163            │ 30               │
# │ Model Size      │ 76.6MiB        │ 76.6MiB          │
# └─────────────────┴────────────────┴──────────────────┘

# %% [markdown]
# # 推論テスト

# %%
import onnxruntime

# モデル読み込み
onnx_session = onnxruntime.InferenceSession(
    'my_rtdetrv2_r18vd.onnx',
    providers=[
        'CPUExecutionProvider',
    ],
)
input_size = onnx_session.get_inputs()[0].shape
input_width, input_height = input_size[3], input_size[2]

print(onnx_session.get_providers())
print('input size:',input_size)
# Out:
# ['CPUExecutionProvider']
# input size: ['N', 3, 640, 640]

# %%
import cv2
import numpy as np

# 画像読み込み
image = cv2.imread('/content/YOLOX-Colaboratory-Training-Sample/02.annotation_data/000001.jpg')
image_height, image_width, _ = image.shape
original_size = np.array([[image_width, image_height]], dtype=np.int64)

# 前処理：BGR->RGB、リサイズ、正規化、NCHW
input_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
input_image = cv2.resize(input_image, (input_width, input_height))
input_image = input_image.astype(np.float32) / 255.0
input_image = np.transpose(input_image, (2, 0, 1))
input_image = np.expand_dims(input_image, axis=0)

# %%
# %%time

# 推論
output = onnx_session.run(
    None,
    input_feed={'images': input_image, "orig_target_sizes": original_size}
)

labels, bboxes, scores = output
# Out:
# CPU times: user 1.38 s, sys: 36.6 ms, total: 1.41 s
# Wall time: 357 ms

# %% [markdown]
# # 結果確認

# %%
import copy

# 描画
debug_image = copy.deepcopy(image)
score_threshold = 0.6

for label, bbox, score in zip(labels[0], bboxes[0], scores[0]):
    if score < score_threshold:
        continue

    cv2.rectangle(
        debug_image,
        (int(bbox[0]), int(bbox[1])),
        (int(bbox[2]), int(bbox[3])),
        (0, 255, 0),
        2,
    )
    cv2.putText(
        debug_image,
        str(label),
        (int(bbox[0]), int(bbox[1]-8)),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.7,
        (0, 255, 0),
        2,
    )

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(debug_image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540>
