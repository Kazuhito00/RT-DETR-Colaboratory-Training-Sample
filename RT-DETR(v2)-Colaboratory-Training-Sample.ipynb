# %% [markdown]
# # リポジトリクローン

# %%
# !git clone https://github.com/lyuwenyu/RT-DETR
# %cd RT-DETR/rtdetrv2_pytorch
# Out:
# Cloning into 'RT-DETR'...
# remote: Enumerating objects: 1020, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 1020 (delta 145), reused 120 (delta 120), pack-reused 800 (from 1)
# Receiving objects: 100% (1020/1020), 626.16 KiB | 13.04 MiB/s, done.
# Resolving deltas: 100% (496/496), done.
# /content/RT-DETR/rtdetrv2_pytorch

# %%
# !mkdir checkpoints

# %% [markdown]
# # パッケージインストール

# %%
# !pip install -q torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q faster-coco-eval
# !pip install -q onnx onnxruntime onnxsim
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 82.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 109.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 103.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00

# %% [markdown]
# # データセット準備（VOC→COCO形式）

# %%
# %cd /content
# !git clone https://github.com/Kazuhito00/YOLOX-Colaboratory-Training-Sample.git
# !git clone https://github.com/Kazuhito00/convert_voc_to_coco.git
# %cd RT-DETR/rtdetrv2_pytorch
# Out:
# /content
# Cloning into 'YOLOX-Colaboratory-Training-Sample'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 187 (delta 22), reused 18 (delta 18), pack-reused 161 (from 1)
# Receiving objects: 100% (187/187), 30.13 MiB | 45.58 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into 'convert_voc_to_coco'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 12), reused 14 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 11.77 KiB | 1.96 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/RT-DETR/rtdetrv2_pytorch

# %%
dataset_directory = '/content/YOLOX-Colaboratory-Training-Sample/02.annotation_data'

# %%
import os

# 学習/検証データパス(train/validation data path)
train_directory = './train'
validation_directory = './validation'

# 学習データ格納ディレクトリ作成(Create training data storage directory)
os.makedirs(train_directory, exist_ok=True)
# 検証データ格納ディレクトリ作成(Create verification data storage directory)
os.makedirs(validation_directory, exist_ok=True)

# %%
import glob
import shutil
import random

# 学習データの割合(Percentage of training data)
train_ratio = 0.8

# コピー元ファイルリスト取得(Get copy source file list)
annotation_list = sorted(glob.glob(dataset_directory + '/*.xml'))
image_list = sorted(glob.glob(dataset_directory + '/*.jpg'))

file_num = len(annotation_list)

# インデックスシャッフル(shuffle)
index_list = list(range(file_num - 1))
random.shuffle(index_list)

for count, index in enumerate(index_list):
    if count < int(file_num * train_ratio):
        # 学習用データ(Training Data)
        shutil.copy2(annotation_list[index], train_directory)
        shutil.copy2(image_list[index], train_directory)
    else:
        # 検証用データ(Validation Data)
        shutil.copy2(annotation_list[index], validation_directory)
        shutil.copy2(image_list[index], validation_directory)

# %%
# Pascal VOC形式 を MS COCO形式へ変換
# !python ../../convert_voc_to_coco/convert_voc_to_coco.py \
    train train/train_annotations.json \
    --start_image_id=0
# !python ../../convert_voc_to_coco/convert_voc_to_coco.py \
    validation validation/validation_annotations.json \
    --start_image_id=10000000
# Out:
# Number of xml files: 40
# Convert XML to JSON: 100% 40/40 [00:00<00:00, 7636.42it/s]
# {'Fish': 221}
# Success: train/train_annotations.json
# Number of xml files: 9
# Convert XML to JSON: 100% 9/9 [00:00<00:00, 7070.38it/s]
# {'Fish': 48}
# Success: validation/validation_annotations.json

# %% [markdown]
# # 学習設定yml準備

# %%
# %%writefile my_coco_detection.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/dataset/coco_detection.yml を参考
#
# task: detection
#
# evaluator:
#   type: CocoEvaluator
#   iou_types: ['bbox', ]
#
# num_classes: 2                                # 変更(実際のクラス数+1を設定)
# remap_mscoco_category: False                  # 変更
#
# train_dataloader:
#   type: DataLoader
#   dataset:
#     type: CocoDetection
#     img_folder: ./train/                      # 変更
#     ann_file: ./train/train_annotations.json  # 変更
#     return_masks: False
#     transforms:
#       type: Compose
#       ops: ~
#   shuffle: True
#   num_workers: 4
#   drop_last: True
#   collate_fn:
#     type: BatchImageCollateFuncion
#
#
# val_dataloader:
#   type: DataLoader
#   dataset:
#     type: CocoDetection
#     img_folder: ./validation/                           # 変更
#     ann_file: ./validation/validation_annotations.json  # 変更
#     return_masks: False
#     transforms:
#       type: Compose
#       ops: ~
#   shuffle: False
#   num_workers: 4
#   drop_last: False
#   collate_fn:
#     type: BatchImageCollateFuncion
# Out:
# Writing my_coco_detection.yml

# %%
# %%writefile my_runtime.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/runtime.yml を参考（今回のサンプルでは変更なし）
#
# print_freq: 100
# output_dir: './logs'
# checkpoint_freq: 1
#
#
# sync_bn: True
# find_unused_parameters: False
#
#
# use_amp: False
# scaler:
#   type: GradScaler
#   enabled: True
#
#
# use_ema: False
# ema:
#   type: ModelEMA
#   decay: 0.9999
#   warmups: 2000
# Out:
# Writing my_runtime.yml

# %%
# %%writefile my_dataloader.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/dataloader.yml を参考（今回のサンプルでは変更なし）
#
#
# train_dataloader:
#   dataset:
#     transforms:
#       ops:
#         - {type: RandomPhotometricDistort, p: 0.5}
#         - {type: RandomZoomOut, fill: 0}
#         - {type: RandomIoUCrop, p: 0.8}
#         - {type: SanitizeBoundingBoxes, min_size: 1}
#         - {type: RandomHorizontalFlip}
#         - {type: Resize, size: [640, 640], }
#         - {type: SanitizeBoundingBoxes, min_size: 1}
#         - {type: ConvertPILImage, dtype: 'float32', scale: True}
#         - {type: ConvertBoxes, fmt: 'cxcywh', normalize: True}
#       policy:
#         name: stop_epoch
#         epoch: 71 # epoch in [71, ~) stop `ops`
#         ops: ['RandomPhotometricDistort', 'RandomZoomOut', 'RandomIoUCrop']
#
#   collate_fn:
#     type: BatchImageCollateFuncion
#     scales: [480, 512, 544, 576, 608, 640, 640, 640, 672, 704, 736, 768, 800]
#     stop_epoch: 71 # epoch in [71, ~) stop `multiscales`
#
#   shuffle: True
#   total_batch_size: 16 # total batch size equals to 16 (4 * 4)
#   num_workers: 4
#
#
# val_dataloader:
#   dataset:
#     transforms:
#       ops:
#         - {type: Resize, size: [640, 640]}
#         - {type: ConvertPILImage, dtype: 'float32', scale: True}
#   shuffle: False
#   total_batch_size: 32
#   num_workers: 4
# Out:
# Writing my_dataloader.yml

# %%
# %%writefile my_optimizer.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/optimizer.yml を参考（今回のサンプルでは変更なし）
#
# use_amp: True
# use_ema: True
# ema:
#   type: ModelEMA
#   decay: 0.9999
#   warmups: 2000
#
#
# epoches: 72
# clip_max_norm: 0.1
#
#
# optimizer:
#   type: AdamW
#   params:
#     -
#       params: '^(?=.*backbone)(?!.*norm).*$'
#       lr: 0.00001
#     -
#       params: '^(?=.*(?:encoder|decoder))(?=.*(?:norm|bn)).*$'
#       weight_decay: 0.
#
#   lr: 0.0001
#   betas: [0.9, 0.999]
#   weight_decay: 0.0001
#
#
# lr_scheduler:
#   type: MultiStepLR
#   milestones: [1000]
#   gamma: 0.1
#
#
# lr_warmup_scheduler:
#   type: LinearWarmup
#   warmup_duration: 2000
# Out:
# Writing my_optimizer.yml

# %%
# %%writefile my_rtdetrv2_r50vd.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/include/rtdetrv2_r50vd.yml を参考（今回のサンプルでは変更なし）
#
# task: detection
#
# model: RTDETR
# criterion: RTDETRCriterionv2
# postprocessor: RTDETRPostProcessor
#
#
# use_focal_loss: True
# eval_spatial_size: [640, 640] # h w
#
#
# RTDETR:
#   backbone: PResNet
#   encoder: HybridEncoder
#   decoder: RTDETRTransformerv2
#
#
# PResNet:
#   depth: 50
#   variant: d
#   freeze_at: 0
#   return_idx: [1, 2, 3]
#   num_stages: 4
#   freeze_norm: True
#   pretrained: True
#
#
# HybridEncoder:
#   in_channels: [512, 1024, 2048]
#   feat_strides: [8, 16, 32]
#
#   # intra
#   hidden_dim: 256
#   use_encoder_idx: [2]
#   num_encoder_layers: 1
#   nhead: 8
#   dim_feedforward: 1024
#   dropout: 0.
#   enc_act: 'gelu'
#
#   # cross
#   expansion: 1.0
#   depth_mult: 1
#   act: 'silu'
#
#
# RTDETRTransformerv2:
#   feat_channels: [256, 256, 256]
#   feat_strides: [8, 16, 32]
#   hidden_dim: 256
#   num_levels: 3
#
#   num_layers: 6
#   num_queries: 300
#
#   num_denoising: 100
#   label_noise_ratio: 0.5
#   box_noise_scale: 1.0 # 1.0 0.4
#
#   eval_idx: -1
#
#   # NEW
#   num_points: [4, 4, 4] # [3,3,3] [2,2,2]
#   cross_attn_method: default # default, discrete
#   query_select_method: default # default, agnostic
#
#
# RTDETRPostProcessor:
#   num_top_queries: 300
#
#
# RTDETRCriterionv2:
#   weight_dict: {loss_vfl: 1, loss_bbox: 5, loss_giou: 2,}
#   losses: ['vfl', 'boxes', ]
#   alpha: 0.75
#   gamma: 2.0
#
#   matcher:
#     type: HungarianMatcher
#     weight_dict: {cost_class: 2, cost_bbox: 5, cost_giou: 2}
#     alpha: 0.25
#     gamma: 2.0
# Out:
# Writing my_rtdetrv2_r50vd.yml

# %%
# %%writefile my_rtdetrv2_r18vd.yml
#
# # RT-DETR/rtdetrv2_pytorch/configs/rtdetrv2/rtdetrv2_r18vd_120e_coco.yml を参考
#
# __include__: [
#   './my_coco_detection.yml',            # 変更
#   './my_runtime.yml',                   # 変更
#   './my_dataloader.yml',                # 変更
#   './my_optimizer.yml',                 # 変更
#   './my_rtdetrv2_r50vd.yml',            # 変更
# ]
#
#
# output_dir: ./output/my_rtdetrv2_r18vd  # 変更
#
#
# PResNet:
#   depth: 18
#   freeze_at: -1
#   freeze_norm: False
#   pretrained: True
#
#
# HybridEncoder:
#   in_channels: [128, 256, 512]
#   hidden_dim: 256
#   expansion: 0.5
#
#
# RTDETRTransformerv2:
#   num_layers: 3
#
#
# epoches: 300                            # 変更
#
# optimizer:
#   type: AdamW
#   params:
#     -
#       params: '^(?=.*(?:norm|bn)).*$'
#       weight_decay: 0.
#
#
# train_dataloader:
#   dataset:
#     transforms:
#       policy:
#         epoch: 117
#   collate_fn:
#     scales: ~
# Out:
# Writing my_rtdetrv2_r18vd.yml

# %% [markdown]
# # 学習実施

# %%
# !CUDA_VISIBLE_DEVICES=0 torchrun --nproc_per_node=1 tools/train.py -c my_rtdetrv2_r18vd.yml --use-amp --seed=0 2>&1 | tee training.log
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
# best_stat: {'epoch': 106, 'coco_eval_bbox': 0.04406807772432528}
# Epoch: [108]  [0/2]  eta: 0:00:04  lr: 0.000011  loss: 16.2306 (16.2306)  loss_vfl: 0.6133 (0.6133)  loss_bbox: 0.5722 (0.5722)  loss_giou: 1.1752 (1.1752)  loss_vfl_aux_0: 0.5332 (0.5332)  loss_bbox_aux_0: 0.6075 (0.6075)  loss_giou_aux_0: 1.2042 (1.2042)  loss_vfl_aux_1: 0.5796 (0.5796)  loss_bbox_aux_1: 0.5777 (0.5777)  loss_giou_aux_1: 1.1833 (1.1833)  loss_vfl_dn_0: 0.3225 (0.3225)  loss_bbox_dn_0: 0.6118 (0.6118)  loss_giou_dn_0: 1.3477 (1.3477)  loss_vfl_dn_1: 0.3284 (0.3284)  loss_bbox_dn_1: 0.6060 (0.6060)  loss_giou_dn_1: 1.3208 (1.3208)  loss_vfl_dn_2: 0.3345 (0.3345)  loss_bbox_dn_2: 0.6001 (0.6001)  loss_giou_dn_2: 1.3016 (1.3016)  loss_vfl_enc_0: 0.4102 (0.4102)  loss_bbox_enc_0: 0.6966 (0.6966)  loss_giou_enc_0: 1.3043 (1.3043)  time: 2.4430  data: 1.7227  max mem: 6525
# Epoch: [108]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.4871 (15.8588)  loss_vfl: 0.6133 (0.6177)  loss_bbox: 0.4795 (0.5258)  loss_giou: 1.1467 (1.1610)  loss_vfl_aux_0: 0.5332 (0.5457)  loss_bbox_aux_0: 0.5118 (0.5597)  loss_giou_aux_0: 1.1886 (1.1964)  loss_vfl_aux_1: 0.5796 (0.5881)  loss_bbox_aux_1: 0.5016 (0.5397)  loss_giou_aux_1: 1.1547 (1.1690)  loss_vfl_dn_0: 0.3191 (0.3208)  loss_bbox_dn_0: 0.5132 (0.5625)  loss_giou_dn_0: 1.3384 (1.3431)  loss_vfl_dn_1: 0.3254 (0.3269)  loss_bbox_dn_1: 0.5083 (0.5572)  loss_giou_dn_1: 1.3192 (1.3200)  loss_vfl_dn_2: 0.3328 (0.3336)  loss_bbox_dn_2: 0.5031 (0.5516)  loss_giou_dn_2: 1.3016 (1.3027)  loss_vfl_enc_0: 0.4102 (0.4254)  loss_bbox_enc_0: 0.5908 (0.6437)  loss_giou_enc_0: 1.2325 (1.2684)  time: 1.5574  data: 0.8614  max mem: 6525
# Epoch: [108] Total time: 0:00:03 (1.5927 s / it)
# Averaged stats: lr: 0.000011  loss: 15.4871 (15.8588)  loss_vfl: 0.6133 (0.6177)  loss_bbox: 0.4795 (0.5258)  loss_giou: 1.1467 (1.1610)  loss_vfl_aux_0: 0.5332 (0.5457)  loss_bbox_aux_0: 0.5118 (0.5597)  loss_giou_aux_0: 1.1886 (1.1964)  loss_vfl_aux_1: 0.5796 (0.5881)  loss_bbox_aux_1: 0.5016 (0.5397)  loss_giou_aux_1: 1.1547 (1.1690)  loss_vfl_dn_0: 0.3191 (0.3208)  loss_bbox_dn_0: 0.5132 (0.5625)  loss_giou_dn_0: 1.3384 (1.3431)  loss_vfl_dn_1: 0.3254 (0.3269)  loss_bbox_dn_1: 0.5083 (0.5572)  loss_giou_dn_1: 1.3192 (1.3200)  loss_vfl_dn_2: 0.3328 (0.3336)  loss_bbox_dn_2: 0.5031 (0.5516)  loss_giou_dn_2: 1.3016 (1.3027)  loss_vfl_enc_0: 0.4102 (0.4254)  loss_bbox_enc_0: 0.5908 (0.6437)  loss_giou_enc_0: 1.2325 (1.2684)
# Test:  [0/1]  eta: 0:00:00    time: 0.7283  data: 0.4438  max mem: 6525
# Test: Total time: 0:00:00 (0.7853 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
# best_stat: {'epoch': 106, 'coco_eval_bbox': 0.04406807772432528}
# Epoch: [109]  [0/2]  eta: 0:00:04  lr: 0.000011  loss: 15.4311 (15.4311)  loss_vfl: 0.5962 (0.5962)  loss_bbox: 0.4980 (0.4980)  loss_giou: 1.1146 (1.1146)  loss_vfl_aux_0: 0.5479 (0.5479)  loss_bbox_aux_0: 0.5056 (0.5056)  loss_giou_aux_0: 1.1537 (1.1537)  loss_vfl_aux_1: 0.5571 (0.5571)  loss_bbox_aux_1: 0.5074 (0.5074)  loss_giou_aux_1: 1.1436 (1.1436)  loss_vfl_dn_0: 0.3181 (0.3181)  loss_bbox_dn_0: 0.5378 (0.5378)  loss_giou_dn_0: 1.3460 (1.3460)  loss_vfl_dn_1: 0.3279 (0.3279)  loss_bbox_dn_1: 0.5297 (0.5297)  loss_giou_dn_1: 1.3169 (1.3169)  loss_vfl_dn_2: 0.3394 (0.3394)  loss_bbox_dn_2: 0.5226 (0.5226)  loss_giou_dn_2: 1.2959 (1.2959)  loss_vfl_enc_0: 0.4600 (0.4600)  loss_bbox_enc_0: 0.6040 (0.6040)  loss_giou_enc_0: 1.2087 (1.2087)  time: 2.4136  data: 1.7023  max mem: 6525
# Epoch: [109]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.4311 (15.7530)  loss_vfl: 0.5054 (0.5508)  loss_bbox: 0.4980 (0.5574)  loss_giou: 1.1146 (1.1878)  loss_vfl_aux_0: 0.4648 (0.5063)  loss_bbox_aux_0: 0.5056 (0.5615)  loss_giou_aux_0: 1.1537 (1.2186)  loss_vfl_aux_1: 0.4827 (0.5199)  loss_bbox_aux_1: 0.5074 (0.5606)  loss_giou_aux_1: 1.1436 (1.2118)  loss_vfl_dn_0: 0.3181 (0.3190)  loss_bbox_dn_0: 0.5199 (0.5289)  loss_giou_dn_0: 1.3460 (1.3525)  loss_vfl_dn_1: 0.3252 (0.3265)  loss_bbox_dn_1: 0.5151 (0.5224)  loss_giou_dn_1: 1.3169 (1.3271)  loss_vfl_dn_2: 0.3357 (0.3375)  loss_bbox_dn_2: 0.5103 (0.5165)  loss_giou_dn_2: 1.2959 (1.3087)  loss_vfl_enc_0: 0.4102 (0.4351)  loss_bbox_enc_0: 0.6040 (0.6455)  loss_giou_enc_0: 1.2087 (1.2587)  time: 1.5428  data: 0.8512  max mem: 6525
# Epoch: [109] Total time: 0:00:03 (1.5740 s / it)
# Averaged stats: lr: 0.000011  loss: 15.4311 (15.7530)  loss_vfl: 0.5054 (0.5508)  loss_bbox: 0.4980 (0.5574)  loss_giou: 1.1146 (1.1878)  loss_vfl_aux_0: 0.4648 (0.5063)  loss_bbox_aux_0: 0.5056 (0.5615)  loss_giou_aux_0: 1.1537 (1.2186)  loss_vfl_aux_1: 0.4827 (0.5199)  loss_bbox_aux_1: 0.5074 (0.5606)  loss_giou_aux_1: 1.1436 (1.2118)  loss_vfl_dn_0: 0.3181 (0.3190)  loss_bbox_dn_0: 0.5199 (0.5289)  loss_giou_dn_0: 1.3460 (1.3525)  loss_vfl_dn_1: 0.3252 (0.3265)  loss_bbox_dn_1: 0.5151 (0.5224)  loss_giou_dn_1: 1.3169 (1.3271)  loss_vfl_dn_2: 0.3357 (0.3375)  loss_bbox_dn_2: 0.5103 (0.5165)  loss_giou_dn_2: 1.2959 (1.3087)  loss_vfl_enc_0: 0.4102 (0.4351)  loss_bbox_enc_0: 0.6040 (0.6455)  loss_giou_enc_0: 1.2087 (1.2587)
# Test:  [0/1]  eta: 0:00:00    time: 0.7111  data: 0.4474  max mem: 6525
# Test: Total time: 0:00:00 (0.7666 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
# best_stat: {'epoch': 109, 'coco_eval_bbox': 0.04592899734157843}
# Epoch: [110]  [0/2]  eta: 0:00:04  lr: 0.000011  loss: 15.8979 (15.8979)  loss_vfl: 0.5903 (0.5903)  loss_bbox: 0.5685 (0.5685)  loss_giou: 1.1535 (1.1535)  loss_vfl_aux_0: 0.5498 (0.5498)  loss_bbox_aux_0: 0.5724 (0.5724)  loss_giou_aux_0: 1.1729 (1.1729)  loss_vfl_aux_1: 0.5610 (0.5610)  loss_bbox_aux_1: 0.5649 (0.5649)  loss_giou_aux_1: 1.1590 (1.1590)  loss_vfl_dn_0: 0.3208 (0.3208)  loss_bbox_dn_0: 0.5930 (0.5930)  loss_giou_dn_0: 1.3346 (1.3346)  loss_vfl_dn_1: 0.3279 (0.3279)  loss_bbox_dn_1: 0.5860 (0.5860)  loss_giou_dn_1: 1.3078 (1.3078)  loss_vfl_dn_2: 0.3420 (0.3420)  loss_bbox_dn_2: 0.5793 (0.5793)  loss_giou_dn_2: 1.2872 (1.2872)  loss_vfl_enc_0: 0.4873 (0.4873)  loss_bbox_enc_0: 0.6232 (0.6232)  loss_giou_enc_0: 1.2164 (1.2164)  time: 2.2260  data: 1.5132  max mem: 6525
# Epoch: [110]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.4884 (15.6932)  loss_vfl: 0.5151 (0.5527)  loss_bbox: 0.5132 (0.5409)  loss_giou: 1.1535 (1.1958)  loss_vfl_aux_0: 0.4568 (0.5033)  loss_bbox_aux_0: 0.5304 (0.5514)  loss_giou_aux_0: 1.1729 (1.2220)  loss_vfl_aux_1: 0.5083 (0.5347)  loss_bbox_aux_1: 0.5100 (0.5375)  loss_giou_aux_1: 1.1590 (1.2069)  loss_vfl_dn_0: 0.3042 (0.3125)  loss_bbox_dn_0: 0.4876 (0.5403)  loss_giou_dn_0: 1.3346 (1.3561)  loss_vfl_dn_1: 0.3113 (0.3196)  loss_bbox_dn_1: 0.4809 (0.5335)  loss_giou_dn_1: 1.3078 (1.3283)  loss_vfl_dn_2: 0.3274 (0.3347)  loss_bbox_dn_2: 0.4747 (0.5270)  loss_giou_dn_2: 1.2872 (1.3066)  loss_vfl_enc_0: 0.3948 (0.4410)  loss_bbox_enc_0: 0.5823 (0.6027)  loss_giou_enc_0: 1.2164 (1.2457)  time: 1.4472  data: 0.7566  max mem: 6525
# Epoch: [110] Total time: 0:00:02 (1.4855 s / it)
# Averaged stats: lr: 0.000011  loss: 15.4884 (15.6932)  loss_vfl: 0.5151 (0.5527)  loss_bbox: 0.5132 (0.5409)  loss_giou: 1.1535 (1.1958)  loss_vfl_aux_0: 0.4568 (0.5033)  loss_bbox_aux_0: 0.5304 (0.5514)  loss_giou_aux_0: 1.1729 (1.2220)  loss_vfl_aux_1: 0.5083 (0.5347)  loss_bbox_aux_1: 0.5100 (0.5375)  loss_giou_aux_1: 1.1590 (1.2069)  loss_vfl_dn_0: 0.3042 (0.3125)  loss_bbox_dn_0: 0.4876 (0.5403)  loss_giou_dn_0: 1.3346 (1.3561)  loss_vfl_dn_1: 0.3113 (0.3196)  loss_bbox_dn_1: 0.4809 (0.5335)  loss_giou_dn_1: 1.3078 (1.3283)  loss_vfl_dn_2: 0.3274 (0.3347)  loss_bbox_dn_2: 0.4747 (0.5270)  loss_giou_dn_2: 1.2872 (1.3066)  loss_vfl_enc_0: 0.3948 (0.4410)  loss_bbox_enc_0: 0.5823 (0.6027)  loss_giou_enc_0: 1.2164 (1.2457)
# Test:  [0/1]  eta: 0:00:00    time: 0.7264  data: 0.4552  max mem: 6525
# Test: Total time: 0:00:00 (0.7836 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
# best_stat: {'epoch': 110, 'coco_eval_bbox': 0.0480664845555574}
# Epoch: [111]  [0/2]  eta: 0:00:04  lr: 0.000011  loss: 15.4621 (15.4621)  loss_vfl: 0.5811 (0.5811)  loss_bbox: 0.4900 (0.4900)  loss_giou: 1.1643 (1.1643)  loss_vfl_aux_0: 0.5083 (0.5083)  loss_bbox_aux_0: 0.4978 (0.4978)  loss_giou_aux_0: 1.1979 (1.1979)  loss_vfl_aux_1: 0.5605 (0.5605)  loss_bbox_aux_1: 0.4936 (0.4936)  loss_giou_aux_1: 1.1734 (1.1734)  loss_vfl_dn_0: 0.3145 (0.3145)  loss_bbox_dn_0: 0.5251 (0.5251)  loss_giou_dn_0: 1.3402 (1.3402)  loss_vfl_dn_1: 0.3250 (0.3250)  loss_bbox_dn_1: 0.5176 (0.5176)  loss_giou_dn_1: 1.3148 (1.3148)  loss_vfl_dn_2: 0.3367 (0.3367)  loss_bbox_dn_2: 0.5106 (0.5106)  loss_giou_dn_2: 1.2967 (1.2967)  loss_vfl_enc_0: 0.4141 (0.4141)  loss_bbox_enc_0: 0.6228 (0.6228)  loss_giou_enc_0: 1.2773 (1.2773)  time: 2.3380  data: 1.6058  max mem: 6525
# Epoch: [111]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.4621 (15.7957)  loss_vfl: 0.5806 (0.5808)  loss_bbox: 0.4900 (0.5502)  loss_giou: 1.1578 (1.1610)  loss_vfl_aux_0: 0.5083 (0.5164)  loss_bbox_aux_0: 0.4978 (0.5669)  loss_giou_aux_0: 1.1808 (1.1894)  loss_vfl_aux_1: 0.5566 (0.5586)  loss_bbox_aux_1: 0.4936 (0.5413)  loss_giou_aux_1: 1.1734 (1.1810)  loss_vfl_dn_0: 0.3145 (0.3224)  loss_bbox_dn_0: 0.5251 (0.5452)  loss_giou_dn_0: 1.3380 (1.3391)  loss_vfl_dn_1: 0.3250 (0.3307)  loss_bbox_dn_1: 0.5176 (0.5379)  loss_giou_dn_1: 1.3115 (1.3132)  loss_vfl_dn_2: 0.3367 (0.3417)  loss_bbox_dn_2: 0.5106 (0.5313)  loss_giou_dn_2: 1.2933 (1.2950)  loss_vfl_enc_0: 0.4141 (0.4390)  loss_bbox_enc_0: 0.6228 (0.6765)  loss_giou_enc_0: 1.2773 (1.2782)  time: 1.5193  data: 0.8200  max mem: 6525
# Epoch: [111] Total time: 0:00:03 (1.5572 s / it)
# Averaged stats: lr: 0.000011  loss: 15.4621 (15.7957)  loss_vfl: 0.5806 (0.5808)  loss_bbox: 0.4900 (0.5502)  loss_giou: 1.1578 (1.1610)  loss_vfl_aux_0: 0.5083 (0.5164)  loss_bbox_aux_0: 0.4978 (0.5669)  loss_giou_aux_0: 1.1808 (1.1894)  loss_vfl_aux_1: 0.5566 (0.5586)  loss_bbox_aux_1: 0.4936 (0.5413)  loss_giou_aux_1: 1.1734 (1.1810)  loss_vfl_dn_0: 0.3145 (0.3224)  loss_bbox_dn_0: 0.5251 (0.5452)  loss_giou_dn_0: 1.3380 (1.3391)  loss_vfl_dn_1: 0.3250 (0.3307)  loss_bbox_dn_1: 0.5176 (0.5379)  loss_giou_dn_1: 1.3115 (1.3132)  loss_vfl_dn_2: 0.3367 (0.3417)  loss_bbox_dn_2: 0.5106 (0.5313)  loss_giou_dn_2: 1.2933 (1.2950)  loss_vfl_enc_0: 0.4141 (0.4390)  loss_bbox_enc_0: 0.6228 (0.6765)  loss_giou_enc_0: 1.2773 (1.2782)
# Test:  [0/1]  eta: 0:00:00    time: 0.7486  data: 0.4591  max mem: 6525
# Test: Total time: 0:00:00 (0.8006 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.041
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 110, 'coco_eval_bbox': 0.0480664845555574}
# Epoch: [112]  [0/2]  eta: 0:00:05  lr: 0.000011  loss: 16.3189 (16.3189)  loss_vfl: 0.5503 (0.5503)  loss_bbox: 0.6002 (0.6002)  loss_giou: 1.1927 (1.1927)  loss_vfl_aux_0: 0.4988 (0.4988)  loss_bbox_aux_0: 0.6250 (0.6250)  loss_giou_aux_0: 1.2309 (1.2309)  loss_vfl_aux_1: 0.5186 (0.5186)  loss_bbox_aux_1: 0.6082 (0.6082)  loss_giou_aux_1: 1.2076 (1.2076)  loss_vfl_dn_0: 0.3203 (0.3203)  loss_bbox_dn_0: 0.6350 (0.6350)  loss_giou_dn_0: 1.3468 (1.3468)  loss_vfl_dn_1: 0.3259 (0.3259)  loss_bbox_dn_1: 0.6276 (0.6276)  loss_giou_dn_1: 1.3238 (1.3238)  loss_vfl_dn_2: 0.3384 (0.3384)  loss_bbox_dn_2: 0.6208 (0.6208)  loss_giou_dn_2: 1.3074 (1.3074)  loss_vfl_enc_0: 0.4292 (0.4292)  loss_bbox_enc_0: 0.7215 (0.7215)  loss_giou_enc_0: 1.2898 (1.2898)  time: 2.5176  data: 1.7859  max mem: 6525
# Epoch: [112]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.5556 (15.9373)  loss_vfl: 0.5503 (0.5601)  loss_bbox: 0.5085 (0.5544)  loss_giou: 1.1721 (1.1824)  loss_vfl_aux_0: 0.4988 (0.5160)  loss_bbox_aux_0: 0.5179 (0.5715)  loss_giou_aux_0: 1.1905 (1.2107)  loss_vfl_aux_1: 0.5186 (0.5261)  loss_bbox_aux_1: 0.5287 (0.5685)  loss_giou_aux_1: 1.1940 (1.2008)  loss_vfl_dn_0: 0.3203 (0.3243)  loss_bbox_dn_0: 0.5066 (0.5708)  loss_giou_dn_0: 1.3383 (1.3426)  loss_vfl_dn_1: 0.3259 (0.3314)  loss_bbox_dn_1: 0.4984 (0.5630)  loss_giou_dn_1: 1.3079 (1.3159)  loss_vfl_dn_2: 0.3384 (0.3423)  loss_bbox_dn_2: 0.4915 (0.5561)  loss_giou_dn_2: 1.2886 (1.2980)  loss_vfl_enc_0: 0.4292 (0.4331)  loss_bbox_enc_0: 0.6346 (0.6780)  loss_giou_enc_0: 1.2898 (1.2913)  time: 1.5928  data: 0.8930  max mem: 6525
# Epoch: [112] Total time: 0:00:03 (1.6232 s / it)
# Averaged stats: lr: 0.000011  loss: 15.5556 (15.9373)  loss_vfl: 0.5503 (0.5601)  loss_bbox: 0.5085 (0.5544)  loss_giou: 1.1721 (1.1824)  loss_vfl_aux_0: 0.4988 (0.5160)  loss_bbox_aux_0: 0.5179 (0.5715)  loss_giou_aux_0: 1.1905 (1.2107)  loss_vfl_aux_1: 0.5186 (0.5261)  loss_bbox_aux_1: 0.5287 (0.5685)  loss_giou_aux_1: 1.1940 (1.2008)  loss_vfl_dn_0: 0.3203 (0.3243)  loss_bbox_dn_0: 0.5066 (0.5708)  loss_giou_dn_0: 1.3383 (1.3426)  loss_vfl_dn_1: 0.3259 (0.3314)  loss_bbox_dn_1: 0.4984 (0.5630)  loss_giou_dn_1: 1.3079 (1.3159)  loss_vfl_dn_2: 0.3384 (0.3423)  loss_bbox_dn_2: 0.4915 (0.5561)  loss_giou_dn_2: 1.2886 (1.2980)  loss_vfl_enc_0: 0.4292 (0.4331)  loss_bbox_enc_0: 0.6346 (0.6780)  loss_giou_enc_0: 1.2898 (1.2913)
# Test:  [0/1]  eta: 0:00:00    time: 0.7413  data: 0.4566  max mem: 6525
# Test: Total time: 0:00:00 (0.7954 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 112, 'coco_eval_bbox': 0.04937918384298465}
# Epoch: [113]  [0/2]  eta: 0:00:04  lr: 0.000011  loss: 15.8838 (15.8838)  loss_vfl: 0.6240 (0.6240)  loss_bbox: 0.5578 (0.5578)  loss_giou: 1.0613 (1.0613)  loss_vfl_aux_0: 0.5781 (0.5781)  loss_bbox_aux_0: 0.5638 (0.5638)  loss_giou_aux_0: 1.0924 (1.0924)  loss_vfl_aux_1: 0.6196 (0.6196)  loss_bbox_aux_1: 0.5517 (0.5517)  loss_giou_aux_1: 1.0816 (1.0816)  loss_vfl_dn_0: 0.3345 (0.3345)  loss_bbox_dn_0: 0.6494 (0.6494)  loss_giou_dn_0: 1.3478 (1.3478)  loss_vfl_dn_1: 0.3342 (0.3342)  loss_bbox_dn_1: 0.6405 (0.6405)  loss_giou_dn_1: 1.3214 (1.3214)  loss_vfl_dn_2: 0.3447 (0.3447)  loss_bbox_dn_2: 0.6325 (0.6325)  loss_giou_dn_2: 1.3012 (1.3012)  loss_vfl_enc_0: 0.5259 (0.5259)  loss_bbox_enc_0: 0.5952 (0.5952)  loss_giou_enc_0: 1.1263 (1.1263)  time: 2.3241  data: 1.5970  max mem: 6525
# Epoch: [113]  [1/2]  eta: 0:00:01  lr: 0.000011  loss: 15.8838 (15.9302)  loss_vfl: 0.5781 (0.6011)  loss_bbox: 0.5578 (0.5603)  loss_giou: 1.0613 (1.1114)  loss_vfl_aux_0: 0.5513 (0.5647)  loss_bbox_aux_0: 0.5638 (0.5724)  loss_giou_aux_0: 1.0924 (1.1334)  loss_vfl_aux_1: 0.5679 (0.5938)  loss_bbox_aux_1: 0.5517 (0.5590)  loss_giou_aux_1: 1.0816 (1.1231)  loss_vfl_dn_0: 0.3276 (0.3311)  loss_bbox_dn_0: 0.5779 (0.6137)  loss_giou_dn_0: 1.3194 (1.3336)  loss_vfl_dn_1: 0.3342 (0.3354)  loss_bbox_dn_1: 0.5699 (0.6052)  loss_giou_dn_1: 1.2939 (1.3076)  loss_vfl_dn_2: 0.3447 (0.3477)  loss_bbox_dn_2: 0.5625 (0.5975)  loss_giou_dn_2: 1.2742 (1.2877)  loss_vfl_enc_0: 0.5054 (0.5156)  loss_bbox_enc_0: 0.5952 (0.6373)  loss_giou_enc_0: 1.1263 (1.1987)  time: 1.5233  data: 0.8226  max mem: 6525
# Epoch: [113] Total time: 0:00:03 (1.5565 s / it)
# Averaged stats: lr: 0.000011  loss: 15.8838 (15.9302)  loss_vfl: 0.5781 (0.6011)  loss_bbox: 0.5578 (0.5603)  loss_giou: 1.0613 (1.1114)  loss_vfl_aux_0: 0.5513 (0.5647)  loss_bbox_aux_0: 0.5638 (0.5724)  loss_giou_aux_0: 1.0924 (1.1334)  loss_vfl_aux_1: 0.5679 (0.5938)  loss_bbox_aux_1: 0.5517 (0.5590)  loss_giou_aux_1: 1.0816 (1.1231)  loss_vfl_dn_0: 0.3276 (0.3311)  loss_bbox_dn_0: 0.5779 (0.6137)  loss_giou_dn_0: 1.3194 (1.3336)  loss_vfl_dn_1: 0.3342 (0.3354)  loss_bbox_dn_1: 0.5699 (0.6052)  loss_giou_dn_1: 1.2939 (1.3076)  loss_vfl_dn_2: 0.3447 (0.3477)  loss_bbox_dn_2: 0.5625 (0.5975)  loss_giou_dn_2: 1.2742 (1.2877)  loss_vfl_enc_0: 0.5054 (0.5156)  loss_bbox_enc_0: 0.5952 (0.6373)  loss_giou_enc_0: 1.1263 (1.1987)
# Test:  [0/1]  eta: 0:00:01    time: 1.1147  data: 0.4480  max mem: 6525
# Test: Total time: 0:00:01 (1.1743 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 113, 'coco_eval_bbox': 0.051722608309984534}
# Epoch: [114]  [0/2]  eta: 0:00:04  lr: 0.000012  loss: 15.9668 (15.9668)  loss_vfl: 0.5830 (0.5830)  loss_bbox: 0.5649 (0.5649)  loss_giou: 1.1949 (1.1949)  loss_vfl_aux_0: 0.5591 (0.5591)  loss_bbox_aux_0: 0.5566 (0.5566)  loss_giou_aux_0: 1.2094 (1.2094)  loss_vfl_aux_1: 0.5664 (0.5664)  loss_bbox_aux_1: 0.5597 (0.5597)  loss_giou_aux_1: 1.1977 (1.1977)  loss_vfl_dn_0: 0.3228 (0.3228)  loss_bbox_dn_0: 0.5426 (0.5426)  loss_giou_dn_0: 1.3429 (1.3429)  loss_vfl_dn_1: 0.3311 (0.3311)  loss_bbox_dn_1: 0.5350 (0.5350)  loss_giou_dn_1: 1.3107 (1.3107)  loss_vfl_dn_2: 0.3442 (0.3442)  loss_bbox_dn_2: 0.5284 (0.5284)  loss_giou_dn_2: 1.2899 (1.2899)  loss_vfl_enc_0: 0.4099 (0.4099)  loss_bbox_enc_0: 0.6825 (0.6825)  loss_giou_enc_0: 1.3353 (1.3353)  time: 2.4105  data: 1.7001  max mem: 6525
# Epoch: [114]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.5850 (15.7759)  loss_vfl: 0.5830 (0.5901)  loss_bbox: 0.4845 (0.5247)  loss_giou: 1.1656 (1.1802)  loss_vfl_aux_0: 0.5527 (0.5559)  loss_bbox_aux_0: 0.4966 (0.5266)  loss_giou_aux_0: 1.2094 (1.2135)  loss_vfl_aux_1: 0.5664 (0.5728)  loss_bbox_aux_1: 0.4794 (0.5195)  loss_giou_aux_1: 1.1721 (1.1849)  loss_vfl_dn_0: 0.3191 (0.3209)  loss_bbox_dn_0: 0.5002 (0.5214)  loss_giou_dn_0: 1.3429 (1.3430)  loss_vfl_dn_1: 0.3311 (0.3312)  loss_bbox_dn_1: 0.4924 (0.5137)  loss_giou_dn_1: 1.3107 (1.3157)  loss_vfl_dn_2: 0.3376 (0.3409)  loss_bbox_dn_2: 0.4862 (0.5073)  loss_giou_dn_2: 1.2899 (1.3016)  loss_vfl_enc_0: 0.4092 (0.4095)  loss_bbox_enc_0: 0.6392 (0.6609)  loss_giou_enc_0: 1.3353 (1.3416)  time: 1.5365  data: 0.8501  max mem: 6525
# Epoch: [114] Total time: 0:00:03 (1.5633 s / it)
# Averaged stats: lr: 0.000012  loss: 15.5850 (15.7759)  loss_vfl: 0.5830 (0.5901)  loss_bbox: 0.4845 (0.5247)  loss_giou: 1.1656 (1.1802)  loss_vfl_aux_0: 0.5527 (0.5559)  loss_bbox_aux_0: 0.4966 (0.5266)  loss_giou_aux_0: 1.2094 (1.2135)  loss_vfl_aux_1: 0.5664 (0.5728)  loss_bbox_aux_1: 0.4794 (0.5195)  loss_giou_aux_1: 1.1721 (1.1849)  loss_vfl_dn_0: 0.3191 (0.3209)  loss_bbox_dn_0: 0.5002 (0.5214)  loss_giou_dn_0: 1.3429 (1.3430)  loss_vfl_dn_1: 0.3311 (0.3312)  loss_bbox_dn_1: 0.4924 (0.5137)  loss_giou_dn_1: 1.3107 (1.3157)  loss_vfl_dn_2: 0.3376 (0.3409)  loss_bbox_dn_2: 0.4862 (0.5073)  loss_giou_dn_2: 1.2899 (1.3016)  loss_vfl_enc_0: 0.4092 (0.4095)  loss_bbox_enc_0: 0.6392 (0.6609)  loss_giou_enc_0: 1.3353 (1.3416)
# Test:  [0/1]  eta: 0:00:00    time: 0.7200  data: 0.4524  max mem: 6525
# Test: Total time: 0:00:00 (0.7741 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 113, 'coco_eval_bbox': 0.051722608309984534}
# Epoch: [115]  [0/2]  eta: 0:00:04  lr: 0.000012  loss: 15.0466 (15.0466)  loss_vfl: 0.6055 (0.6055)  loss_bbox: 0.4415 (0.4415)  loss_giou: 1.1044 (1.1044)  loss_vfl_aux_0: 0.5679 (0.5679)  loss_bbox_aux_0: 0.4537 (0.4537)  loss_giou_aux_0: 1.1272 (1.1272)  loss_vfl_aux_1: 0.5786 (0.5786)  loss_bbox_aux_1: 0.4414 (0.4414)  loss_giou_aux_1: 1.1059 (1.1059)  loss_vfl_dn_0: 0.3140 (0.3140)  loss_bbox_dn_0: 0.4950 (0.4950)  loss_giou_dn_0: 1.3421 (1.3421)  loss_vfl_dn_1: 0.3284 (0.3284)  loss_bbox_dn_1: 0.4849 (0.4849)  loss_giou_dn_1: 1.3040 (1.3040)  loss_vfl_dn_2: 0.3423 (0.3423)  loss_bbox_dn_2: 0.4767 (0.4767)  loss_giou_dn_2: 1.2803 (1.2803)  loss_vfl_enc_0: 0.4353 (0.4353)  loss_bbox_enc_0: 0.5605 (0.5605)  loss_giou_enc_0: 1.2572 (1.2572)  time: 2.3590  data: 1.6898  max mem: 6525
# Epoch: [115]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.0466 (15.2162)  loss_vfl: 0.6055 (0.6262)  loss_bbox: 0.4415 (0.4570)  loss_giou: 1.0654 (1.0849)  loss_vfl_aux_0: 0.5679 (0.5847)  loss_bbox_aux_0: 0.4537 (0.4749)  loss_giou_aux_0: 1.0877 (1.1075)  loss_vfl_aux_1: 0.5786 (0.5999)  loss_bbox_aux_1: 0.4414 (0.4617)  loss_giou_aux_1: 1.0576 (1.0818)  loss_vfl_dn_0: 0.3113 (0.3126)  loss_bbox_dn_0: 0.4950 (0.5298)  loss_giou_dn_0: 1.3421 (1.3487)  loss_vfl_dn_1: 0.3242 (0.3263)  loss_bbox_dn_1: 0.4849 (0.5201)  loss_giou_dn_1: 1.3040 (1.3115)  loss_vfl_dn_2: 0.3345 (0.3384)  loss_bbox_dn_2: 0.4767 (0.5124)  loss_giou_dn_2: 1.2803 (1.2882)  loss_vfl_enc_0: 0.4353 (0.4562)  loss_bbox_enc_0: 0.5605 (0.5782)  loss_giou_enc_0: 1.1734 (1.2153)  time: 1.5176  data: 0.8450  max mem: 6525
# Epoch: [115] Total time: 0:00:03 (1.5502 s / it)
# Averaged stats: lr: 0.000012  loss: 15.0466 (15.2162)  loss_vfl: 0.6055 (0.6262)  loss_bbox: 0.4415 (0.4570)  loss_giou: 1.0654 (1.0849)  loss_vfl_aux_0: 0.5679 (0.5847)  loss_bbox_aux_0: 0.4537 (0.4749)  loss_giou_aux_0: 1.0877 (1.1075)  loss_vfl_aux_1: 0.5786 (0.5999)  loss_bbox_aux_1: 0.4414 (0.4617)  loss_giou_aux_1: 1.0576 (1.0818)  loss_vfl_dn_0: 0.3113 (0.3126)  loss_bbox_dn_0: 0.4950 (0.5298)  loss_giou_dn_0: 1.3421 (1.3487)  loss_vfl_dn_1: 0.3242 (0.3263)  loss_bbox_dn_1: 0.4849 (0.5201)  loss_giou_dn_1: 1.3040 (1.3115)  loss_vfl_dn_2: 0.3345 (0.3384)  loss_bbox_dn_2: 0.4767 (0.5124)  loss_giou_dn_2: 1.2803 (1.2882)  loss_vfl_enc_0: 0.4353 (0.4562)  loss_bbox_enc_0: 0.5605 (0.5782)  loss_giou_enc_0: 1.1734 (1.2153)
# Test:  [0/1]  eta: 0:00:00    time: 0.7294  data: 0.4550  max mem: 6525
# Test: Total time: 0:00:00 (0.7925 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 113, 'coco_eval_bbox': 0.051722608309984534}
# Epoch: [116]  [0/2]  eta: 0:00:04  lr: 0.000012  loss: 16.8971 (16.8971)  loss_vfl: 0.6113 (0.6113)  loss_bbox: 0.6587 (0.6587)  loss_giou: 1.1637 (1.1637)  loss_vfl_aux_0: 0.5371 (0.5371)  loss_bbox_aux_0: 0.6875 (0.6875)  loss_giou_aux_0: 1.2023 (1.2023)  loss_vfl_aux_1: 0.5801 (0.5801)  loss_bbox_aux_1: 0.6646 (0.6646)  loss_giou_aux_1: 1.1954 (1.1954)  loss_vfl_dn_0: 0.3235 (0.3235)  loss_bbox_dn_0: 0.7120 (0.7120)  loss_giou_dn_0: 1.3543 (1.3543)  loss_vfl_dn_1: 0.3281 (0.3281)  loss_bbox_dn_1: 0.7041 (0.7041)  loss_giou_dn_1: 1.3320 (1.3320)  loss_vfl_dn_2: 0.3359 (0.3359)  loss_bbox_dn_2: 0.6971 (0.6971)  loss_giou_dn_2: 1.3170 (1.3170)  loss_vfl_enc_0: 0.5073 (0.5073)  loss_bbox_enc_0: 0.7517 (0.7517)  loss_giou_enc_0: 1.2335 (1.2335)  time: 2.2980  data: 1.5837  max mem: 6525
# Epoch: [116]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.3585 (16.1278)  loss_vfl: 0.5957 (0.6035)  loss_bbox: 0.4944 (0.5766)  loss_giou: 1.1153 (1.1395)  loss_vfl_aux_0: 0.5371 (0.5381)  loss_bbox_aux_0: 0.5048 (0.5962)  loss_giou_aux_0: 1.1596 (1.1810)  loss_vfl_aux_1: 0.5664 (0.5732)  loss_bbox_aux_1: 0.5109 (0.5878)  loss_giou_aux_1: 1.1166 (1.1560)  loss_vfl_dn_0: 0.3154 (0.3195)  loss_bbox_dn_0: 0.5358 (0.6239)  loss_giou_dn_0: 1.3417 (1.3480)  loss_vfl_dn_1: 0.3276 (0.3279)  loss_bbox_dn_1: 0.5255 (0.6148)  loss_giou_dn_1: 1.3052 (1.3186)  loss_vfl_dn_2: 0.3359 (0.3392)  loss_bbox_dn_2: 0.5174 (0.6072)  loss_giou_dn_2: 1.2808 (1.2989)  loss_vfl_enc_0: 0.4780 (0.4927)  loss_bbox_enc_0: 0.5674 (0.6595)  loss_giou_enc_0: 1.2183 (1.2259)  time: 1.4981  data: 0.8077  max mem: 6525
# Epoch: [116] Total time: 0:00:03 (1.5334 s / it)
# Averaged stats: lr: 0.000012  loss: 15.3585 (16.1278)  loss_vfl: 0.5957 (0.6035)  loss_bbox: 0.4944 (0.5766)  loss_giou: 1.1153 (1.1395)  loss_vfl_aux_0: 0.5371 (0.5381)  loss_bbox_aux_0: 0.5048 (0.5962)  loss_giou_aux_0: 1.1596 (1.1810)  loss_vfl_aux_1: 0.5664 (0.5732)  loss_bbox_aux_1: 0.5109 (0.5878)  loss_giou_aux_1: 1.1166 (1.1560)  loss_vfl_dn_0: 0.3154 (0.3195)  loss_bbox_dn_0: 0.5358 (0.6239)  loss_giou_dn_0: 1.3417 (1.3480)  loss_vfl_dn_1: 0.3276 (0.3279)  loss_bbox_dn_1: 0.5255 (0.6148)  loss_giou_dn_1: 1.3052 (1.3186)  loss_vfl_dn_2: 0.3359 (0.3392)  loss_bbox_dn_2: 0.5174 (0.6072)  loss_giou_dn_2: 1.2808 (1.2989)  loss_vfl_enc_0: 0.4780 (0.4927)  loss_bbox_enc_0: 0.5674 (0.6595)  loss_giou_enc_0: 1.2183 (1.2259)
# Test:  [0/1]  eta: 0:00:00    time: 0.7369  data: 0.4437  max mem: 6525
# Test: Total time: 0:00:00 (0.7951 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 113, 'coco_eval_bbox': 0.051722608309984534}
# Epoch: [117]  [0/2]  eta: 0:00:02  lr: 0.000012  loss: 15.8011 (15.8011)  loss_vfl: 0.6636 (0.6636)  loss_bbox: 0.5057 (0.5057)  loss_giou: 1.0090 (1.0090)  loss_vfl_aux_0: 0.6260 (0.6260)  loss_bbox_aux_0: 0.5194 (0.5194)  loss_giou_aux_0: 1.0612 (1.0612)  loss_vfl_aux_1: 0.6621 (0.6621)  loss_bbox_aux_1: 0.5132 (0.5132)  loss_giou_aux_1: 1.0208 (1.0208)  loss_vfl_dn_0: 0.3325 (0.3325)  loss_bbox_dn_0: 0.6837 (0.6837)  loss_giou_dn_0: 1.3551 (1.3551)  loss_vfl_dn_1: 0.3379 (0.3379)  loss_bbox_dn_1: 0.6720 (0.6720)  loss_giou_dn_1: 1.3200 (1.3200)  loss_vfl_dn_2: 0.3472 (0.3472)  loss_bbox_dn_2: 0.6621 (0.6621)  loss_giou_dn_2: 1.2932 (1.2932)  loss_vfl_enc_0: 0.5469 (0.5469)  loss_bbox_enc_0: 0.5613 (0.5613)  loss_giou_enc_0: 1.1082 (1.1082)  time: 1.3764  data: 0.6987  max mem: 6525
# Epoch: [117]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.3635 (15.5823)  loss_vfl: 0.5464 (0.6050)  loss_bbox: 0.4997 (0.5027)  loss_giou: 1.0090 (1.0689)  loss_vfl_aux_0: 0.5176 (0.5718)  loss_bbox_aux_0: 0.5098 (0.5146)  loss_giou_aux_0: 1.0612 (1.1175)  loss_vfl_aux_1: 0.5425 (0.6023)  loss_bbox_aux_1: 0.4978 (0.5055)  loss_giou_aux_1: 1.0208 (1.0813)  loss_vfl_dn_0: 0.3325 (0.3352)  loss_bbox_dn_0: 0.5730 (0.6283)  loss_giou_dn_0: 1.3305 (1.3428)  loss_vfl_dn_1: 0.3379 (0.3458)  loss_bbox_dn_1: 0.5608 (0.6164)  loss_giou_dn_1: 1.2928 (1.3064)  loss_vfl_dn_2: 0.3472 (0.3575)  loss_bbox_dn_2: 0.5507 (0.6064)  loss_giou_dn_2: 1.2654 (1.2793)  loss_vfl_enc_0: 0.4541 (0.5005)  loss_bbox_enc_0: 0.5265 (0.5439)  loss_giou_enc_0: 1.1082 (1.1500)  time: 1.0465  data: 0.3669  max mem: 6525
# Epoch: [117] Total time: 0:00:02 (1.0791 s / it)
# Averaged stats: lr: 0.000012  loss: 15.3635 (15.5823)  loss_vfl: 0.5464 (0.6050)  loss_bbox: 0.4997 (0.5027)  loss_giou: 1.0090 (1.0689)  loss_vfl_aux_0: 0.5176 (0.5718)  loss_bbox_aux_0: 0.5098 (0.5146)  loss_giou_aux_0: 1.0612 (1.1175)  loss_vfl_aux_1: 0.5425 (0.6023)  loss_bbox_aux_1: 0.4978 (0.5055)  loss_giou_aux_1: 1.0208 (1.0813)  loss_vfl_dn_0: 0.3325 (0.3352)  loss_bbox_dn_0: 0.5730 (0.6283)  loss_giou_dn_0: 1.3305 (1.3428)  loss_vfl_dn_1: 0.3379 (0.3458)  loss_bbox_dn_1: 0.5608 (0.6164)  loss_giou_dn_1: 1.2928 (1.3064)  loss_vfl_dn_2: 0.3472 (0.3575)  loss_bbox_dn_2: 0.5507 (0.6064)  loss_giou_dn_2: 1.2654 (1.2793)  loss_vfl_enc_0: 0.4541 (0.5005)  loss_bbox_enc_0: 0.5265 (0.5439)  loss_giou_enc_0: 1.1082 (1.1500)
# Test:  [0/1]  eta: 0:00:00    time: 0.7637  data: 0.4628  max mem: 6525
# Test: Total time: 0:00:00 (0.8204 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 117, 'coco_eval_bbox': 0.06082044291355964}
# Epoch: [118]  [0/2]  eta: 0:00:02  lr: 0.000012  loss: 15.4017 (15.4017)  loss_vfl: 0.6455 (0.6455)  loss_bbox: 0.4701 (0.4701)  loss_giou: 0.9982 (0.9982)  loss_vfl_aux_0: 0.6084 (0.6084)  loss_bbox_aux_0: 0.4985 (0.4985)  loss_giou_aux_0: 1.0282 (1.0282)  loss_vfl_aux_1: 0.6470 (0.6470)  loss_bbox_aux_1: 0.4840 (0.4840)  loss_giou_aux_1: 0.9997 (0.9997)  loss_vfl_dn_0: 0.3396 (0.3396)  loss_bbox_dn_0: 0.6517 (0.6517)  loss_giou_dn_0: 1.3436 (1.3436)  loss_vfl_dn_1: 0.3430 (0.3430)  loss_bbox_dn_1: 0.6396 (0.6396)  loss_giou_dn_1: 1.3088 (1.3088)  loss_vfl_dn_2: 0.3547 (0.3547)  loss_bbox_dn_2: 0.6295 (0.6295)  loss_giou_dn_2: 1.2826 (1.2826)  loss_vfl_enc_0: 0.5308 (0.5308)  loss_bbox_enc_0: 0.5223 (0.5223)  loss_giou_enc_0: 1.0761 (1.0761)  time: 1.4045  data: 0.7309  max mem: 6525
# Epoch: [118]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.4017 (15.4728)  loss_vfl: 0.5625 (0.6040)  loss_bbox: 0.4701 (0.4875)  loss_giou: 0.9982 (1.0697)  loss_vfl_aux_0: 0.5332 (0.5708)  loss_bbox_aux_0: 0.4985 (0.5108)  loss_giou_aux_0: 1.0282 (1.1038)  loss_vfl_aux_1: 0.5439 (0.5955)  loss_bbox_aux_1: 0.4840 (0.4961)  loss_giou_aux_1: 0.9997 (1.0837)  loss_vfl_dn_0: 0.3396 (0.3418)  loss_bbox_dn_0: 0.5852 (0.6184)  loss_giou_dn_0: 1.3222 (1.3329)  loss_vfl_dn_1: 0.3430 (0.3485)  loss_bbox_dn_1: 0.5736 (0.6066)  loss_giou_dn_1: 1.2850 (1.2969)  loss_vfl_dn_2: 0.3547 (0.3624)  loss_bbox_dn_2: 0.5644 (0.5969)  loss_giou_dn_2: 1.2584 (1.2705)  loss_vfl_enc_0: 0.4556 (0.4932)  loss_bbox_enc_0: 0.5223 (0.5314)  loss_giou_enc_0: 1.0761 (1.1514)  time: 1.0443  data: 0.3655  max mem: 6525
# Epoch: [118] Total time: 0:00:02 (1.0760 s / it)
# Averaged stats: lr: 0.000012  loss: 15.4017 (15.4728)  loss_vfl: 0.5625 (0.6040)  loss_bbox: 0.4701 (0.4875)  loss_giou: 0.9982 (1.0697)  loss_vfl_aux_0: 0.5332 (0.5708)  loss_bbox_aux_0: 0.4985 (0.5108)  loss_giou_aux_0: 1.0282 (1.1038)  loss_vfl_aux_1: 0.5439 (0.5955)  loss_bbox_aux_1: 0.4840 (0.4961)  loss_giou_aux_1: 0.9997 (1.0837)  loss_vfl_dn_0: 0.3396 (0.3418)  loss_bbox_dn_0: 0.5852 (0.6184)  loss_giou_dn_0: 1.3222 (1.3329)  loss_vfl_dn_1: 0.3430 (0.3485)  loss_bbox_dn_1: 0.5736 (0.6066)  loss_giou_dn_1: 1.2850 (1.2969)  loss_vfl_dn_2: 0.3547 (0.3624)  loss_bbox_dn_2: 0.5644 (0.5969)  loss_giou_dn_2: 1.2584 (1.2705)  loss_vfl_enc_0: 0.4556 (0.4932)  loss_bbox_enc_0: 0.5223 (0.5314)  loss_giou_enc_0: 1.0761 (1.1514)
# Test:  [0/1]  eta: 0:00:00    time: 0.7161  data: 0.4521  max mem: 6525
# Test: Total time: 0:00:00 (0.7706 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
# best_stat: {'epoch': 117, 'coco_eval_bbox': 0.06082044291355964}
# Epoch: [119]  [0/2]  eta: 0:00:02  lr: 0.000012  loss: 15.7427 (15.7427)  loss_vfl: 0.6475 (0.6475)  loss_bbox: 0.4946 (0.4946)  loss_giou: 1.0546 (1.0546)  loss_vfl_aux_0: 0.5747 (0.5747)  loss_bbox_aux_0: 0.5187 (0.5187)  loss_giou_aux_0: 1.1183 (1.1183)  loss_vfl_aux_1: 0.6221 (0.6221)  loss_bbox_aux_1: 0.5015 (0.5015)  loss_giou_aux_1: 1.0687 (1.0687)  loss_vfl_dn_0: 0.3386 (0.3386)  loss_bbox_dn_0: 0.6714 (0.6714)  loss_giou_dn_0: 1.3393 (1.3393)  loss_vfl_dn_1: 0.3455 (0.3455)  loss_bbox_dn_1: 0.6581 (0.6581)  loss_giou_dn_1: 1.3007 (1.3007)  loss_vfl_dn_2: 0.3564 (0.3564)  loss_bbox_dn_2: 0.6475 (0.6475)  loss_giou_dn_2: 1.2726 (1.2726)  loss_vfl_enc_0: 0.5088 (0.5088)  loss_bbox_enc_0: 0.5570 (0.5570)  loss_giou_enc_0: 1.1462 (1.1462)  time: 1.3667  data: 0.6760  max mem: 6525
# Epoch: [119]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.3167 (15.5297)  loss_vfl: 0.6021 (0.6248)  loss_bbox: 0.4909 (0.4927)  loss_giou: 1.0546 (1.0651)  loss_vfl_aux_0: 0.5747 (0.5796)  loss_bbox_aux_0: 0.4979 (0.5083)  loss_giou_aux_0: 1.0792 (1.0987)  loss_vfl_aux_1: 0.5859 (0.6040)  loss_bbox_aux_1: 0.4951 (0.4983)  loss_giou_aux_1: 1.0687 (1.0739)  loss_vfl_dn_0: 0.3306 (0.3346)  loss_bbox_dn_0: 0.5923 (0.6319)  loss_giou_dn_0: 1.3393 (1.3396)  loss_vfl_dn_1: 0.3376 (0.3416)  loss_bbox_dn_1: 0.5795 (0.6188)  loss_giou_dn_1: 1.3007 (1.3008)  loss_vfl_dn_2: 0.3528 (0.3546)  loss_bbox_dn_2: 0.5690 (0.6083)  loss_giou_dn_2: 1.2726 (1.2729)  loss_vfl_enc_0: 0.4954 (0.5021)  loss_bbox_enc_0: 0.5236 (0.5403)  loss_giou_enc_0: 1.1318 (1.1390)  time: 1.0467  data: 0.3558  max mem: 6525
# Epoch: [119] Total time: 0:00:02 (1.0761 s / it)
# Averaged stats: lr: 0.000012  loss: 15.3167 (15.5297)  loss_vfl: 0.6021 (0.6248)  loss_bbox: 0.4909 (0.4927)  loss_giou: 1.0546 (1.0651)  loss_vfl_aux_0: 0.5747 (0.5796)  loss_bbox_aux_0: 0.4979 (0.5083)  loss_giou_aux_0: 1.0792 (1.0987)  loss_vfl_aux_1: 0.5859 (0.6040)  loss_bbox_aux_1: 0.4951 (0.4983)  loss_giou_aux_1: 1.0687 (1.0739)  loss_vfl_dn_0: 0.3306 (0.3346)  loss_bbox_dn_0: 0.5923 (0.6319)  loss_giou_dn_0: 1.3393 (1.3396)  loss_vfl_dn_1: 0.3376 (0.3416)  loss_bbox_dn_1: 0.5795 (0.6188)  loss_giou_dn_1: 1.3007 (1.3008)  loss_vfl_dn_2: 0.3528 (0.3546)  loss_bbox_dn_2: 0.5690 (0.6083)  loss_giou_dn_2: 1.2726 (1.2729)  loss_vfl_enc_0: 0.4954 (0.5021)  loss_bbox_enc_0: 0.5236 (0.5403)  loss_giou_enc_0: 1.1318 (1.1390)
# Test:  [0/1]  eta: 0:00:00    time: 0.7483  data: 0.4575  max mem: 6525
# Test: Total time: 0:00:00 (0.8022 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.082
# best_stat: {'epoch': 117, 'coco_eval_bbox': 0.06082044291355964}
# Epoch: [120]  [0/2]  eta: 0:00:02  lr: 0.000012  loss: 15.5416 (15.5416)  loss_vfl: 0.6860 (0.6860)  loss_bbox: 0.4840 (0.4840)  loss_giou: 1.0046 (1.0046)  loss_vfl_aux_0: 0.6270 (0.6270)  loss_bbox_aux_0: 0.5005 (0.5005)  loss_giou_aux_0: 1.0346 (1.0346)  loss_vfl_aux_1: 0.6792 (0.6792)  loss_bbox_aux_1: 0.4859 (0.4859)  loss_giou_aux_1: 1.0081 (1.0081)  loss_vfl_dn_0: 0.3376 (0.3376)  loss_bbox_dn_0: 0.6621 (0.6621)  loss_giou_dn_0: 1.3322 (1.3322)  loss_vfl_dn_1: 0.3430 (0.3430)  loss_bbox_dn_1: 0.6492 (0.6492)  loss_giou_dn_1: 1.2927 (1.2927)  loss_vfl_dn_2: 0.3567 (0.3567)  loss_bbox_dn_2: 0.6384 (0.6384)  loss_giou_dn_2: 1.2633 (1.2633)  loss_vfl_enc_0: 0.5400 (0.5400)  loss_bbox_enc_0: 0.5300 (0.5300)  loss_giou_enc_0: 1.0864 (1.0864)  time: 1.3729  data: 0.6971  max mem: 6525
# Epoch: [120]  [1/2]  eta: 0:00:01  lr: 0.000012  loss: 15.2244 (15.3830)  loss_vfl: 0.6606 (0.6733)  loss_bbox: 0.4750 (0.4795)  loss_giou: 0.9906 (0.9976)  loss_vfl_aux_0: 0.6040 (0.6155)  loss_bbox_aux_0: 0.4902 (0.4953)  loss_giou_aux_0: 1.0288 (1.0317)  loss_vfl_aux_1: 0.6582 (0.6687)  loss_bbox_aux_1: 0.4821 (0.4840)  loss_giou_aux_1: 0.9972 (1.0027)  loss_vfl_dn_0: 0.3315 (0.3346)  loss_bbox_dn_0: 0.6241 (0.6431)  loss_giou_dn_0: 1.3198 (1.3260)  loss_vfl_dn_1: 0.3384 (0.3407)  loss_bbox_dn_1: 0.6098 (0.6295)  loss_giou_dn_1: 1.2781 (1.2854)  loss_vfl_dn_2: 0.3540 (0.3553)  loss_bbox_dn_2: 0.5985 (0.6185)  loss_giou_dn_2: 1.2490 (1.2562)  loss_vfl_enc_0: 0.5029 (0.5215)  loss_bbox_enc_0: 0.5300 (0.5372)  loss_giou_enc_0: 1.0864 (1.0867)  time: 1.0430  data: 0.3649  max mem: 6525
# Epoch: [120] Total time: 0:00:02 (1.0713 s / it)
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.685
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.612
# best_stat: {'epoch': 295, 'coco_eval_bbox': 0.3076200134649716}
# Epoch: [296]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 6.4108 (6.4108)  loss_vfl: 0.3853 (0.3853)  loss_bbox: 0.0465 (0.0465)  loss_giou: 0.1443 (0.1443)  loss_vfl_aux_0: 0.5239 (0.5239)  loss_bbox_aux_0: 0.0684 (0.0684)  loss_giou_aux_0: 0.2128 (0.2128)  loss_vfl_aux_1: 0.4138 (0.4138)  loss_bbox_aux_1: 0.0512 (0.0512)  loss_giou_aux_1: 0.1672 (0.1672)  loss_vfl_dn_0: 0.4316 (0.4316)  loss_bbox_dn_0: 0.3354 (0.3354)  loss_giou_dn_0: 0.7666 (0.7666)  loss_vfl_dn_1: 0.3987 (0.3987)  loss_bbox_dn_1: 0.1865 (0.1865)  loss_giou_dn_1: 0.4651 (0.4651)  loss_vfl_dn_2: 0.3794 (0.3794)  loss_bbox_dn_2: 0.1362 (0.1362)  loss_giou_dn_2: 0.3519 (0.3519)  loss_vfl_enc_0: 0.4878 (0.4878)  loss_bbox_enc_0: 0.1113 (0.1113)  loss_giou_enc_0: 0.3469 (0.3469)  time: 1.4363  data: 0.7588  max mem: 6525
# Epoch: [296]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 6.1532 (6.2820)  loss_vfl: 0.3853 (0.4137)  loss_bbox: 0.0465 (0.0479)  loss_giou: 0.1443 (0.1485)  loss_vfl_aux_0: 0.5239 (0.5369)  loss_bbox_aux_0: 0.0642 (0.0663)  loss_giou_aux_0: 0.2097 (0.2113)  loss_vfl_aux_1: 0.4138 (0.4312)  loss_bbox_aux_1: 0.0485 (0.0498)  loss_giou_aux_1: 0.1536 (0.1604)  loss_vfl_dn_0: 0.4316 (0.4346)  loss_bbox_dn_0: 0.2981 (0.3167)  loss_giou_dn_0: 0.7118 (0.7392)  loss_vfl_dn_1: 0.3796 (0.3892)  loss_bbox_dn_1: 0.1592 (0.1728)  loss_giou_dn_1: 0.3987 (0.4319)  loss_vfl_dn_2: 0.3547 (0.3671)  loss_bbox_dn_2: 0.1192 (0.1277)  loss_giou_dn_2: 0.3041 (0.3280)  loss_vfl_enc_0: 0.4878 (0.4884)  loss_bbox_enc_0: 0.0976 (0.1045)  loss_giou_enc_0: 0.2852 (0.3161)  time: 1.0799  data: 0.3982  max mem: 6525
# Epoch: [296] Total time: 0:00:02 (1.1109 s / it)
# Averaged stats: lr: 0.000030  loss: 6.1532 (6.2820)  loss_vfl: 0.3853 (0.4137)  loss_bbox: 0.0465 (0.0479)  loss_giou: 0.1443 (0.1485)  loss_vfl_aux_0: 0.5239 (0.5369)  loss_bbox_aux_0: 0.0642 (0.0663)  loss_giou_aux_0: 0.2097 (0.2113)  loss_vfl_aux_1: 0.4138 (0.4312)  loss_bbox_aux_1: 0.0485 (0.0498)  loss_giou_aux_1: 0.1536 (0.1604)  loss_vfl_dn_0: 0.4316 (0.4346)  loss_bbox_dn_0: 0.2981 (0.3167)  loss_giou_dn_0: 0.7118 (0.7392)  loss_vfl_dn_1: 0.3796 (0.3892)  loss_bbox_dn_1: 0.1592 (0.1728)  loss_giou_dn_1: 0.3987 (0.4319)  loss_vfl_dn_2: 0.3547 (0.3671)  loss_bbox_dn_2: 0.1192 (0.1277)  loss_giou_dn_2: 0.3041 (0.3280)  loss_vfl_enc_0: 0.4878 (0.4884)  loss_bbox_enc_0: 0.0976 (0.1045)  loss_giou_enc_0: 0.2852 (0.3161)
# Test:  [0/1]  eta: 0:00:00    time: 0.7184  data: 0.4419  max mem: 6525
# Test: Total time: 0:00:00 (0.7717 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.315
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.564
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.267
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.939
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.633
# best_stat: {'epoch': 296, 'coco_eval_bbox': 0.31469712357805}
# Epoch: [297]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 6.7667 (6.7667)  loss_vfl: 0.4949 (0.4949)  loss_bbox: 0.0625 (0.0625)  loss_giou: 0.1802 (0.1802)  loss_vfl_aux_0: 0.5654 (0.5654)  loss_bbox_aux_0: 0.0756 (0.0756)  loss_giou_aux_0: 0.2278 (0.2278)  loss_vfl_aux_1: 0.5059 (0.5059)  loss_bbox_aux_1: 0.0633 (0.0633)  loss_giou_aux_1: 0.1887 (0.1887)  loss_vfl_dn_0: 0.4216 (0.4216)  loss_bbox_dn_0: 0.3295 (0.3295)  loss_giou_dn_0: 0.7789 (0.7789)  loss_vfl_dn_1: 0.3933 (0.3933)  loss_bbox_dn_1: 0.1901 (0.1901)  loss_giou_dn_1: 0.4787 (0.4787)  loss_vfl_dn_2: 0.3772 (0.3772)  loss_bbox_dn_2: 0.1394 (0.1394)  loss_giou_dn_2: 0.3655 (0.3655)  loss_vfl_enc_0: 0.5005 (0.5005)  loss_bbox_enc_0: 0.1102 (0.1102)  loss_giou_enc_0: 0.3175 (0.3175)  time: 1.3628  data: 0.6896  max mem: 6525
# Epoch: [297]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 6.5872 (6.6770)  loss_vfl: 0.4131 (0.4540)  loss_bbox: 0.0568 (0.0597)  loss_giou: 0.1802 (0.1884)  loss_vfl_aux_0: 0.5420 (0.5537)  loss_bbox_aux_0: 0.0731 (0.0744)  loss_giou_aux_0: 0.2278 (0.2328)  loss_vfl_aux_1: 0.4329 (0.4694)  loss_bbox_aux_1: 0.0609 (0.0621)  loss_giou_aux_1: 0.1887 (0.1949)  loss_vfl_dn_0: 0.4216 (0.4268)  loss_bbox_dn_0: 0.3054 (0.3175)  loss_giou_dn_0: 0.7708 (0.7749)  loss_vfl_dn_1: 0.3933 (0.3979)  loss_bbox_dn_1: 0.1713 (0.1807)  loss_giou_dn_1: 0.4782 (0.4785)  loss_vfl_dn_2: 0.3772 (0.3800)  loss_bbox_dn_2: 0.1273 (0.1333)  loss_giou_dn_2: 0.3655 (0.3711)  loss_vfl_enc_0: 0.4688 (0.4846)  loss_bbox_enc_0: 0.1102 (0.1102)  loss_giou_enc_0: 0.3175 (0.3321)  time: 1.0383  data: 0.3618  max mem: 6525
# Epoch: [297] Total time: 0:00:02 (1.0674 s / it)
# Averaged stats: lr: 0.000030  loss: 6.5872 (6.6770)  loss_vfl: 0.4131 (0.4540)  loss_bbox: 0.0568 (0.0597)  loss_giou: 0.1802 (0.1884)  loss_vfl_aux_0: 0.5420 (0.5537)  loss_bbox_aux_0: 0.0731 (0.0744)  loss_giou_aux_0: 0.2278 (0.2328)  loss_vfl_aux_1: 0.4329 (0.4694)  loss_bbox_aux_1: 0.0609 (0.0621)  loss_giou_aux_1: 0.1887 (0.1949)  loss_vfl_dn_0: 0.4216 (0.4268)  loss_bbox_dn_0: 0.3054 (0.3175)  loss_giou_dn_0: 0.7708 (0.7749)  loss_vfl_dn_1: 0.3933 (0.3979)  loss_bbox_dn_1: 0.1713 (0.1807)  loss_giou_dn_1: 0.4782 (0.4785)  loss_vfl_dn_2: 0.3772 (0.3800)  loss_bbox_dn_2: 0.1273 (0.1333)  loss_giou_dn_2: 0.3655 (0.3711)  loss_vfl_enc_0: 0.4688 (0.4846)  loss_bbox_enc_0: 0.1102 (0.1102)  loss_giou_enc_0: 0.3175 (0.3321)
# Test:  [0/1]  eta: 0:00:01    time: 1.1463  data: 0.4560  max mem: 6525
# Test: Total time: 0:00:01 (1.2038 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.592
# best_stat: {'epoch': 296, 'coco_eval_bbox': 0.31469712357805}
# Epoch: [298]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 6.2901 (6.2901)  loss_vfl: 0.3677 (0.3677)  loss_bbox: 0.0471 (0.0471)  loss_giou: 0.1593 (0.1593)  loss_vfl_aux_0: 0.5278 (0.5278)  loss_bbox_aux_0: 0.0740 (0.0740)  loss_giou_aux_0: 0.2227 (0.2227)  loss_vfl_aux_1: 0.3992 (0.3992)  loss_bbox_aux_1: 0.0557 (0.0557)  loss_giou_aux_1: 0.1819 (0.1819)  loss_vfl_dn_0: 0.4363 (0.4363)  loss_bbox_dn_0: 0.3142 (0.3142)  loss_giou_dn_0: 0.7396 (0.7396)  loss_vfl_dn_1: 0.3955 (0.3955)  loss_bbox_dn_1: 0.1731 (0.1731)  loss_giou_dn_1: 0.4449 (0.4449)  loss_vfl_dn_2: 0.3738 (0.3738)  loss_bbox_dn_2: 0.1284 (0.1284)  loss_giou_dn_2: 0.3427 (0.3427)  loss_vfl_enc_0: 0.5010 (0.5010)  loss_bbox_enc_0: 0.0995 (0.0995)  loss_giou_enc_0: 0.3058 (0.3058)  time: 1.4149  data: 0.7344  max mem: 6525
# Epoch: [298]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 6.2901 (6.3125)  loss_vfl: 0.3599 (0.3638)  loss_bbox: 0.0471 (0.0507)  loss_giou: 0.1593 (0.1678)  loss_vfl_aux_0: 0.4812 (0.5045)  loss_bbox_aux_0: 0.0638 (0.0689)  loss_giou_aux_0: 0.2135 (0.2181)  loss_vfl_aux_1: 0.3848 (0.3920)  loss_bbox_aux_1: 0.0557 (0.0577)  loss_giou_aux_1: 0.1819 (0.1898)  loss_vfl_dn_0: 0.4363 (0.4390)  loss_bbox_dn_0: 0.3121 (0.3131)  loss_giou_dn_0: 0.7396 (0.7445)  loss_vfl_dn_1: 0.3955 (0.4011)  loss_bbox_dn_1: 0.1731 (0.1741)  loss_giou_dn_1: 0.4449 (0.4511)  loss_vfl_dn_2: 0.3738 (0.3788)  loss_bbox_dn_2: 0.1280 (0.1282)  loss_giou_dn_2: 0.3427 (0.3468)  loss_vfl_enc_0: 0.4875 (0.4943)  loss_bbox_enc_0: 0.0995 (0.1054)  loss_giou_enc_0: 0.3058 (0.3227)  time: 1.0501  data: 0.3673  max mem: 6525
# Epoch: [298] Total time: 0:00:02 (1.0805 s / it)
# Averaged stats: lr: 0.000030  loss: 6.2901 (6.3125)  loss_vfl: 0.3599 (0.3638)  loss_bbox: 0.0471 (0.0507)  loss_giou: 0.1593 (0.1678)  loss_vfl_aux_0: 0.4812 (0.5045)  loss_bbox_aux_0: 0.0638 (0.0689)  loss_giou_aux_0: 0.2135 (0.2181)  loss_vfl_aux_1: 0.3848 (0.3920)  loss_bbox_aux_1: 0.0557 (0.0577)  loss_giou_aux_1: 0.1819 (0.1898)  loss_vfl_dn_0: 0.4363 (0.4390)  loss_bbox_dn_0: 0.3121 (0.3131)  loss_giou_dn_0: 0.7396 (0.7445)  loss_vfl_dn_1: 0.3955 (0.4011)  loss_bbox_dn_1: 0.1731 (0.1741)  loss_giou_dn_1: 0.4449 (0.4511)  loss_vfl_dn_2: 0.3738 (0.3788)  loss_bbox_dn_2: 0.1280 (0.1282)  loss_giou_dn_2: 0.3427 (0.3468)  loss_vfl_enc_0: 0.4875 (0.4943)  loss_bbox_enc_0: 0.0995 (0.1054)  loss_giou_enc_0: 0.3058 (0.3227)
# Test:  [0/1]  eta: 0:00:00    time: 0.7583  data: 0.4664  max mem: 6525
# Test: Total time: 0:00:00 (0.8128 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.469
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.592
# best_stat: {'epoch': 296, 'coco_eval_bbox': 0.31469712357805}
# Epoch: [299]  [0/2]  eta: 0:00:02  lr: 0.000030  loss: 6.2479 (6.2479)  loss_vfl: 0.3625 (0.3625)  loss_bbox: 0.0512 (0.0512)  loss_giou: 0.1560 (0.1560)  loss_vfl_aux_0: 0.4795 (0.4795)  loss_bbox_aux_0: 0.0691 (0.0691)  loss_giou_aux_0: 0.2066 (0.2066)  loss_vfl_aux_1: 0.3833 (0.3833)  loss_bbox_aux_1: 0.0614 (0.0614)  loss_giou_aux_1: 0.1847 (0.1847)  loss_vfl_dn_0: 0.4399 (0.4399)  loss_bbox_dn_0: 0.3073 (0.3073)  loss_giou_dn_0: 0.7409 (0.7409)  loss_vfl_dn_1: 0.4033 (0.4033)  loss_bbox_dn_1: 0.1776 (0.1776)  loss_giou_dn_1: 0.4542 (0.4542)  loss_vfl_dn_2: 0.3823 (0.3823)  loss_bbox_dn_2: 0.1348 (0.1348)  loss_giou_dn_2: 0.3470 (0.3470)  loss_vfl_enc_0: 0.4910 (0.4910)  loss_bbox_enc_0: 0.1036 (0.1036)  loss_giou_enc_0: 0.3114 (0.3114)  time: 1.4251  data: 0.7475  max mem: 6525
# Epoch: [299]  [1/2]  eta: 0:00:01  lr: 0.000030  loss: 6.2479 (6.2925)  loss_vfl: 0.3625 (0.3875)  loss_bbox: 0.0512 (0.0533)  loss_giou: 0.1560 (0.1613)  loss_vfl_aux_0: 0.4795 (0.4883)  loss_bbox_aux_0: 0.0691 (0.0740)  loss_giou_aux_0: 0.2066 (0.2208)  loss_vfl_aux_1: 0.3806 (0.3820)  loss_bbox_aux_1: 0.0613 (0.0613)  loss_giou_aux_1: 0.1847 (0.1852)  loss_vfl_dn_0: 0.4355 (0.4377)  loss_bbox_dn_0: 0.3073 (0.3114)  loss_giou_dn_0: 0.7284 (0.7347)  loss_vfl_dn_1: 0.3901 (0.3967)  loss_bbox_dn_1: 0.1715 (0.1746)  loss_giou_dn_1: 0.4349 (0.4445)  loss_vfl_dn_2: 0.3679 (0.3751)  loss_bbox_dn_2: 0.1275 (0.1312)  loss_giou_dn_2: 0.3371 (0.3421)  loss_vfl_enc_0: 0.4890 (0.4900)  loss_bbox_enc_0: 0.1036 (0.1101)  loss_giou_enc_0: 0.3114 (0.3307)  time: 1.0528  data: 0.3738  max mem: 6525
# Epoch: [299] Total time: 0:00:02 (1.0819 s / it)
# Averaged stats: lr: 0.000030  loss: 6.2479 (6.2925)  loss_vfl: 0.3625 (0.3875)  loss_bbox: 0.0512 (0.0533)  loss_giou: 0.1560 (0.1613)  loss_vfl_aux_0: 0.4795 (0.4883)  loss_bbox_aux_0: 0.0691 (0.0740)  loss_giou_aux_0: 0.2066 (0.2208)  loss_vfl_aux_1: 0.3806 (0.3820)  loss_bbox_aux_1: 0.0613 (0.0613)  loss_giou_aux_1: 0.1847 (0.1852)  loss_vfl_dn_0: 0.4355 (0.4377)  loss_bbox_dn_0: 0.3073 (0.3114)  loss_giou_dn_0: 0.7284 (0.7347)  loss_vfl_dn_1: 0.3901 (0.3967)  loss_bbox_dn_1: 0.1715 (0.1746)  loss_giou_dn_1: 0.4349 (0.4445)  loss_vfl_dn_2: 0.3679 (0.3751)  loss_bbox_dn_2: 0.1275 (0.1312)  loss_giou_dn_2: 0.3371 (0.3421)  loss_vfl_enc_0: 0.4890 (0.4900)  loss_bbox_enc_0: 0.1036 (0.1101)  loss_giou_enc_0: 0.3114 (0.3307)
# Test:  [0/1]  eta: 0:00:00    time: 0.7346  data: 0.4603  max mem: 6525
# Test: Total time: 0:00:00 (0.7987 s / it)
# Averaged stats:
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.592
# best_stat: {'epoch': 296, 'coco_eval_bbox': 0.31469712357805}
# Training time 0:26:17

# %% [markdown]
# # ONNX出力

# %%
# !python tools/export_onnx.py \
    -c my_rtdetrv2_r18vd.yml \
    -r output/my_rtdetrv2_r18vd/best.pth \
    --output_file my_rtdetrv2_r18vd.onnx \
    --check
# Out:
# 2025-03-25 23:47:21.568242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742946441.589936   32898 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742946441.596685   32898 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-25 23:47:21.618852: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/RT-DETR/rtdetrv2_pytorch/tools/export_onnx.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(args.resume, map_location='cpu')
# Load PResNet18 state_dict
# /content/RT-DETR/rtdetrv2_pytorch/tools/../src/zoo/rtdetr/rtdetrv2_decoder.py:141: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if reference_points.shape[-1] == 2:
# /content/RT-DETR/rtdetrv2_pytorch/tools/../src/zoo/rtdetr/rtdetrv2_decoder.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   elif reference_points.shape[-1] == 4:
# Check export onnx model done...

# %%
# !onnxsim my_rtdetrv2_r18vd.onnx my_rtdetrv2_r18vd.onnx
# Out:
# Your model contains "Tile" ops or/and "ConstantOfShape" ops. Folding these ops can make the
# simplified model much larger. If it is not expected, please specify "--no-large-tensor" (which will
# lose some optimization chances)
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃                 ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add             │ 126            │ 117              │
# │ AveragePool     │ 3              │ 3                │
# │ Cast            │ 11             │ 1                │
# │ Clip            │ 9              │ 9                │
# │ Concat          │ 75             │ 32               │
# │ Constant        │ 684            │ 293              │
# │ ConstantOfShape │ 4              │ 0                │
# │ Conv            │ 57             │ 57               │
# │ Div             │ 21             │ 17               │
# │ Erf             │ 1              │ 1                │
# │ Expand          │ 4              │ 0                │
# │ Flatten         │ 1              │ 1                │
# │ Gather          │ 56             │ 17               │
# │ GatherElements  │ 3              │ 3                │
# │ Gemm            │ 4              │ 4                │
# │ GridSample      │ 9              │ 9                │
# │ Identity        │ 6              │ 0                │
# │ Log             │ 3              │ 3                │
# │ MatMul          │ 61             │ 61               │
# │ MaxPool         │ 1              │ 1                │
# │ Mul             │ 83             │ 73               │
# │ Pow             │ 12             │ 12               │
# │ ReduceMax       │ 1              │ 1                │
# │ ReduceMean      │ 24             │ 24               │
# │ ReduceSum       │ 3              │ 3                │
# │ Relu            │ 33             │ 33               │
# │ Reshape         │ 58             │ 55               │
# │ Resize          │ 2              │ 2                │
# │ Shape           │ 67             │ 16               │
# │ Sigmoid         │ 33             │ 33               │
# │ Slice           │ 31             │ 22               │
# │ Softmax         │ 7              │ 7                │
# │ Split           │ 4              │ 4                │
# │ Sqrt            │ 12             │ 12               │
# │ Squeeze         │ 4              │ 4                │
# │ Sub             │ 21             │ 21               │
# │ Tile            │ 4              │ 4                │
# │ TopK            │ 2              │ 2                │
# │ Transpose       │ 45             │ 45               │
# │ Unsqueeze       │ 163            │ 30               │
# │ Model Size      │ 76.6MiB        │ 76.6MiB          │
# └─────────────────┴────────────────┴──────────────────┘

# %% [markdown]
# # 推論テスト

# %%
import onnxruntime

# モデル読み込み
onnx_session = onnxruntime.InferenceSession(
    'my_rtdetrv2_r18vd.onnx',
    providers=[
        'CPUExecutionProvider',
    ],
)
input_size = onnx_session.get_inputs()[0].shape
input_width, input_height = input_size[3], input_size[2]

print(onnx_session.get_providers())
print('input size:',input_size)
# Out:
# ['CPUExecutionProvider']
# input size: ['N', 3, 640, 640]

# %%
import cv2
import numpy as np

# 画像読み込み
image = cv2.imread('/content/YOLOX-Colaboratory-Training-Sample/02.annotation_data/000001.jpg')
image_height, image_width, _ = image.shape
original_size = np.array([[image_width, image_height]], dtype=np.int64)

# 前処理：BGR->RGB、リサイズ、正規化、NCHW
input_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
input_image = cv2.resize(input_image, (input_width, input_height))
input_image = input_image.astype(np.float32) / 255.0
input_image = np.transpose(input_image, (2, 0, 1))
input_image = np.expand_dims(input_image, axis=0)

# %%
# %%time

# 推論
output = onnx_session.run(
    None,
    input_feed={'images': input_image, "orig_target_sizes": original_size}
)

labels, bboxes, scores = output
# Out:
# CPU times: user 1.18 s, sys: 28.1 ms, total: 1.21 s
# Wall time: 305 ms

# %% [markdown]
# # 結果確認

# %%
import copy

# 描画
debug_image = copy.deepcopy(image)
score_threshold = 0.6

for label, bbox, score in zip(labels[0], bboxes[0], scores[0]):
    if score < score_threshold:
        continue

    cv2.rectangle(
        debug_image,
        (int(bbox[0]), int(bbox[1])),
        (int(bbox[2]), int(bbox[3])),
        (0, 255, 0),
        2,
    )
    cv2.putText(
        debug_image,
        str(label),
        (int(bbox[0]), int(bbox[1]-8)),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.7,
        (0, 255, 0),
        2,
    )

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(debug_image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540>
